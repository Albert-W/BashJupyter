# %%
#http://10.120.217.249:9200/adp-app-logs-2021.08.26/_search?size=1000
import requests
baseurl = 'http://10.120.217.249:9200'

# %%
result = requests.get(baseurl)
result.json()
# Out:
# {'name': 'eric-data-search-engine-ingest-895bbccf7-7ddnm',
#  'cluster_name': 'eric-data-search-engine',
#  'cluster_uuid': 'YbusCkk7SxGN2Fp_xdW4Kw',
#  'version': {'number': '7.8.1',
#   'build_flavor': 'oss',
#   'build_type': 'tar',
#   'build_hash': 'b5ca9c58fb664ca8bf9e4057fc229b3396bf3a89',
#   'build_date': '2020-07-21T16:40:44.668009Z',
#   'build_snapshot': False,
#   'lucene_version': '8.5.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
result = requests.get(baseurl + '/_cat/master?v')
result.text
# Out:
# 'id                     host           ip             node\naAF9Ctd2QOqWO6nS0MxmwQ 192.168.140.60 192.168.140.60 eric-data-search-engine-master-2\n'

# %%
result = requests.get(baseurl + '/_cat/master?help')
result.text
# Out:
# 'id   |   | node id    \nhost | h | host name  \nip   |   | ip address \nnode | n | node name  \n'

# %%
result = requests.get(baseurl + '/_cat/master')
result.text
# Out:
# 'aAF9Ctd2QOqWO6nS0MxmwQ 192.168.140.60 192.168.140.60 eric-data-search-engine-master-2\n'

# %%
result = requests.get(baseurl + '/_cat/indices')
result.text
# Out:
# 'green open adp-app-logs-2021.08.26 TCr5eB7PS_adm597pbCmAw 5 1 43 0 472.8kb 236.3kb\ngreen open adp-app-logs-2021.08.25 PHOB-anOS8CVlnk-KoqD5A 5 1 10 0 213.9kb 106.9kb\ngreen open adp-app-logs-2021.08.24 -jM_cvzlQXCHt2k8CA75kQ 5 1 53 0 579.4kb 289.7kb\ngreen open my-index-01             2mnlnLP0RquSvwWrcq4VFw 5 1  0 0     2kb     1kb\n'

# %%
result = requests.get(baseurl + '/_cat/')
print(result.text)
# Out:
# =^.^=
# /_cat/allocation
# /_cat/shards
# /_cat/shards/{index}
# /_cat/master
# /_cat/nodes
# /_cat/tasks
# /_cat/indices
# /_cat/indices/{index}
# /_cat/segments
# /_cat/segments/{index}
# /_cat/count
# /_cat/count/{index}
# /_cat/recovery
# /_cat/recovery/{index}
# /_cat/health
# /_cat/pending_tasks
# /_cat/aliases
# /_cat/aliases/{alias}
# /_cat/thread_pool
# /_cat/thread_pool/{thread_pools}
# /_cat/plugins
# /_cat/fielddata
# /_cat/fielddata/{fields}
# /_cat/nodeattrs
# /_cat/repositories
# /_cat/snapshots/{repository}
# /_cat/templates

# %%
result = requests.put(baseurl + '/my-index-01')
print(result.text)
# Out:
# {"error":{"root_cause":[{"type":"resource_already_exists_exception","reason":"index [my-index-01/2mnlnLP0RquSvwWrcq4VFw] already exists","index_uuid":"2mnlnLP0RquSvwWrcq4VFw","index":"my-index-01"}],"type":"resource_already_exists_exception","reason":"index [my-index-01/2mnlnLP0RquSvwWrcq4VFw] already exists","index_uuid":"2mnlnLP0RquSvwWrcq4VFw","index":"my-index-01"},"status":400}

# %%
result = requests.get(baseurl + '/_cat/indices')
print(result.text)
# Out:
# green open adp-app-logs-2021.08.30 liWAfXR8RxuoZ9W3hhy-UQ 5 1 11 0   203kb  96.3kb
# green open adp-app-logs-2021.08.27 W__DEx4XTUGs_vM2eu1IPg 5 1 72 0 600.5kb 307.2kb
# green open adp-app-logs-2021.08.26 TCr5eB7PS_adm597pbCmAw 5 1 91 0 734.6kb 369.2kb
# green open adp-app-logs-2021.08.25 PHOB-anOS8CVlnk-KoqD5A 5 1 10 0 213.9kb 106.9kb
# green open adp-app-logs-2021.08.24 -jM_cvzlQXCHt2k8CA75kQ 5 1 53 0 579.4kb 289.7kb
# green open my-index-01             2mnlnLP0RquSvwWrcq4VFw 5 1  0 0     2kb     1kb

# %%
result = requests.get(baseurl + '/adp-app-logs-2021.08.26/_search')
result.json()
# Out:
# {'took': 6,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 43, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
#     '_id': 'LJwqgnsBJeAju-avQFbK',
#     '_score': 1.0,
#     '_source': {'port': 8202,
#      'tags': ['_grokparsefailure', 'syslog3164'],
#      'type': 'syslog',
#      '@timestamp': '2021-08-26T11:13:32.230Z',
#      '@version': '1',
#      'logplane': 'adp-app-logs',
#      'version': '1.0.0'}},
#    {'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
#     '_id': 'MJwtgnsBJeAju-avB1af',
#     '_score': 1.0,
#     '_source': {'port': 38723,
#      'tags': ['_grokparsefailure', 'syslog3164'],
#      'type': 'syslog',
#      '@timestamp': '2021-08-26T11:16:34.180Z',
#      '@version': '1',
#      'logplane': 'adp-app-logs',
#      'version': '1.0.0'}},
#    {'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
# ...

# %%
result = requests.get(baseurl + '/adp-app-logs-2021.08.26/_search?pretty=true&q=*:*')
result.json()
# Out:
# {'took': 46,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 43, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
#     '_id': 'LJwqgnsBJeAju-avQFbK',
#     '_score': 1.0,
#     '_source': {'port': 8202,
#      'tags': ['_grokparsefailure', 'syslog3164'],
#      'type': 'syslog',
#      '@timestamp': '2021-08-26T11:13:32.230Z',
#      '@version': '1',
#      'logplane': 'adp-app-logs',
#      'version': '1.0.0'}},
#    {'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
#     '_id': 'MJwtgnsBJeAju-avB1af',
#     '_score': 1.0,
#     '_source': {'port': 38723,
#      'tags': ['_grokparsefailure', 'syslog3164'],
#      'type': 'syslog',
#      '@timestamp': '2021-08-26T11:16:34.180Z',
#      '@version': '1',
#      'logplane': 'adp-app-logs',
#      'version': '1.0.0'}},
#    {'_index': 'adp-app-logs-2021.08.26',
# ...

# %%
body = {
    "size": 10000,
    "query": {
        "match_all": {}
    }
}
url = baseurl + '/adp-app-logs-2021.08.26/_search?scroll=1m'
result = requests.get(url, json = body)
result.json()
# Out:
# {'_scroll_id': '',
#  'took': 12,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 91, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
#     '_id': 'LJwqgnsBJeAju-avQFbK',
#     '_score': 1.0,
#     '_source': {'port': 8202,
#      'tags': ['_grokparsefailure', 'syslog3164'],
#      'type': 'syslog',
#      '@timestamp': '2021-08-26T11:13:32.230Z',
#      '@version': '1',
#      'logplane': 'adp-app-logs',
#      'version': '1.0.0'}},
# ...

# %%
url = baseurl + '/adp-app-logs-2021.08.26/_search?size=1000'
result = requests.get(url, json = body)
result.json()
# Out:
# {'took': 8,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 91, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
#     '_id': 'LJwqgnsBJeAju-avQFbK',
#     '_score': 1.0,
#     '_source': {'port': 8202,
#      'tags': ['_grokparsefailure', 'syslog3164'],
#      'type': 'syslog',
#      '@timestamp': '2021-08-26T11:13:32.230Z',
#      '@version': '1',
#      'logplane': 'adp-app-logs',
#      'version': '1.0.0'}},
#    {'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
#     '_id': 'MJwtgnsBJeAju-avB1af',
#     '_score': 1.0,
#     '_source': {'port': 38723,
#      'tags': ['_grokparsefailure', 'syslog3164'],
#      'type': 'syslog',
#      '@timestamp': '2021-08-26T11:16:34.180Z',
#      '@version': '1',
#      'logplane': 'adp-app-logs',
#      'version': '1.0.0'}},
#    {'_index': 'adp-app-logs-2021.08.26',
#     '_type': '_doc',
# ...

# %% [markdown]
# # CMM Rest Endpoint
#
# demo: http://10.120.217.249:5003/cm/api/v1/configurations/ericsson-brm?jsonpointer=/ericsson-brm:brm/

# %%
import requests
baseurl = 'http://10.120.217.249:5003'

# %%
url = f'{baseurl}/cm/health'
result = requests.get(url)
result.json()
# Out:
# {'message': 'Ready'}

# %% [markdown]
# ## Configuration

# %% [markdown]
# ### list configuration
#
# create a backup: doesn't need ietf-netconf-acm in place
# restore a backup: need ietf-netconf-acm in place

# %%
url = f'{baseurl}/cm/api/v1/configurations'
result = requests.get(url)
result.json()
# Out:
# [{'name': 'ietf-netconf-acm', 'title': ''}]

# %% [markdown]
# ### delete configuration

# %%
url = f'{baseurl}/cm/api/v1/configurations/ericsson-brm'
result = requests.delete(url)
result.json()
# Out:
# {'message': "Deleted configuration 'ericsson-brm'"}

# %% [markdown]
# ### Detail a configuration

# %%
url = f'{baseurl}/cm/api/v1/configurations/ericsson-brm'
result = requests.get(url)
result.json()
# Out:
# {'message': "Cannot find configuration 'ericsson-brm'"}

# %%
url = f'{baseurl}/cm/api/v1/configurations/ietf-netconf-acm'
result = requests.get(url)
result.json()
# Out:
# {'name': 'ietf-netconf-acm',
#  'title': '',
#  'data': {'ietf-netconf-acm:nacm': {'rule-list': [{'name': 'ericsson-cm-yang-provider-1-system-admin',
#      'rule': [{'name': 'ericsson-notification-1-system-admin',
#        'action': 'permit',
#        'module-name': 'ericsson-notifications',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'tailf-confd_dyncfg-1-system-admin',
#        'action': 'permit',
#        'module-name': 'confd_dyncfg',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'tailf-aaa-authentication-1-system-admin',
#        'path': '/alias',
#        'action': 'permit',
#        'module-name': 'tailf-aaa',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-1-system-admin',
#        'action': 'permit',
#        'module-name': 'ietf-netconf',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-notifications-1-system-admin',
#        'action': 'permit',
#        'module-name': 'ietf-netconf-notifications',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-monitoring-1-system-admin',
#        'action': 'permit',
#        'module-name': 'ietf-netconf-monitoring',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-1-system-admin-copy-config',
#        'action': 'permit',
#        'rpc-name': 'copy-config',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-2-system-admin-delete-config',
#        'action': 'permit',
#        'rpc-name': 'delete-config',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-3-system-admin-lock',
#        'action': 'permit',
#        'rpc-name': 'lock',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-4-system-admin-unlock',
#        'action': 'permit',
#        'rpc-name': 'unlock',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-5-system-admin-kill-session',
#        'action': 'permit',
#        'rpc-name': 'kill-session',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'}],
#      'group': ['system-admin'],
#      'tailf-acm:cmdrule': [{'name': 'metrics-query-cmd',
#        'action': 'permit',
#        'command': 'metrics-query',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'xxload-cmd',
#        'action': 'permit',
#        'command': 'xxload',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-alarm-cmd',
#        'action': 'permit',
#        'command': 'show alarm',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-alarm-history-cmd',
#        'action': 'permit',
#        'command': 'show alarm-history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'autowizard-cmd',
#        'action': 'permit',
#        'command': 'autowizard',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'change-password-cmd',
#        'action': 'permit',
#        'command': 'change-password',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'clear-cmd',
#        'action': 'permit',
#        'command': 'clear',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'complete-on-space-cmd',
#        'action': 'permit',
#        'command': 'complete-on-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'describe-cmd',
#        'action': 'permit',
#        'command': 'describe',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-level-cmd',
#        'action': 'permit',
#        'command': 'display-level',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'quit-cmd',
#        'action': 'permit',
#        'command': 'quit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'help-cmd',
#        'action': 'permit',
#        'command': 'help',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'history-cmd',
#        'action': 'permit',
#        'command': 'history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'idle-timeout-cmd',
#        'action': 'permit',
#        'command': 'idle-timeout',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'ignore-leading-space-cmd',
#        'action': 'permit',
#        'command': 'ignore-leading-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'leaf-prompting-cmd',
#        'action': 'permit',
#        'command': 'leaf-prompting',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'no-cmd',
#        'action': 'permit',
#        'command': 'no',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'paginate-cmd',
#        'action': 'permit',
#        'command': 'paginate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'pwd-cmd',
#        'action': 'permit',
#        'command': 'pwd',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-length-cmd',
#        'action': 'permit',
#        'command': 'screen-length',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-width-cmd',
#        'action': 'permit',
#        'command': 'screen-width',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'timestamp-cmd',
#        'action': 'permit',
#        'command': 'timestamp',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'config-cmd',
#        'action': 'permit',
#        'command': 'config',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'abort-cmd',
#        'action': 'permit',
#        'command': 'abort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'commit-cmd',
#        'action': 'permit',
#        'command': 'commit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'compare-cmd',
#        'action': 'permit',
#        'command': 'compare',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'do-cmd',
#        'action': 'permit',
#        'command': 'do',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'end-cmd',
#        'action': 'permit',
#        'command': 'end',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'file-cmd',
#        'action': 'permit',
#        'command': 'file',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'insert-cmd',
#        'action': 'permit',
#        'command': 'insert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'load-cmd',
#        'action': 'permit',
#        'command': 'load',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'move-cmd',
#        'action': 'permit',
#        'command': 'move',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rename-cmd',
#        'action': 'permit',
#        'command': 'rename',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'resolved-cmd',
#        'action': 'permit',
#        'command': 'resolved',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'revert-cmd',
#        'action': 'permit',
#        'command': 'revert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'top-cmd',
#        'action': 'permit',
#        'command': 'top',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'validate-cmd',
#        'action': 'permit',
#        'command': 'validate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-cmd',
#        'action': 'permit',
#        'command': 'show',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rollback-cmd',
#        'action': 'permit',
#        'command': 'rollback',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'save-cmd',
#        'action': 'permit',
#        'command': 'save',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-cmd',
#        'action': 'permit',
#        'command': 'display',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'begin-cmd',
#        'action': 'permit',
#        'command': 'begin',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'best-effort-cmd',
#        'action': 'permit',
#        'command': 'best-effort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'context-match-cmd',
#        'action': 'permit',
#        'command': 'context-match',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'count-cmd',
#        'action': 'permit',
#        'command': 'count',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'csv-cmd',
#        'action': 'permit',
#        'command': 'csv',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'debug-cmd',
#        'action': 'permit',
#        'command': 'debug',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'de-select-cmd',
#        'action': 'permit',
#        'command': 'de-select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'details-cmd',
#        'action': 'permit',
#        'command': 'details',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'exclude-cmd',
#        'action': 'permit',
#        'command': 'exclude',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'extended-cmd',
#        'action': 'permit',
#        'command': 'extended',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'include-cmd',
#        'action': 'permit',
#        'command': 'include',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'linnum-cmd',
#        'action': 'permit',
#        'command': 'linnum',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-all-cmd',
#        'action': 'permit',
#        'command': 'match-all',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-any-cmd',
#        'action': 'permit',
#        'command': 'match-any',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'more-cmd',
#        'action': 'permit',
#        'command': 'more',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'nomore-cmd',
#        'action': 'permit',
#        'command': 'nomore',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'select-cmd',
#        'action': 'permit',
#        'command': 'select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'sort-by-cmd',
#        'action': 'permit',
#        'command': 'sort-by',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'suppress-validate-warning-prompt-cmd',
#        'action': 'permit',
#        'command': 'suppress-validate-warning-prompt',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'tab-cmd',
#        'action': 'permit',
#        'command': 'tab',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'until-cmd',
#        'action': 'permit',
#        'command': 'until',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-defaults-cmd',
#        'action': 'permit',
#        'command': 'show-defaults',
#        'context': 'cli',
#        'access-operations': '*'}]},
#     {'name': 'ericsson-brm-1-system-admin',
#      'rule': [{'name': 'ericsson-brm-system-admin-rule',
#        'action': 'permit',
#        'module-name': 'ericsson-brm',
#        'access-operations': '*',
#        'tailf-acm:context': '*'}],
#      'group': ['system-admin']},
#     {'name': 'ericsson-brm-2-system-read-only',
#      'rule': [{'name': 'ericsson-brm-system-read-only-rule',
#        'action': 'permit',
#        'module-name': 'ericsson-brm',
#        'access-operations': 'read',
#        'tailf-acm:context': '*'}],
#      'group': ['system-read-only']},
#     {'name': 'ericsson-cm-yang-provider-2-system-security-admin',
#      'rule': [{'name': 'ietf-netconf-acm-1-system-security-admin',
#        'action': 'permit',
#        'module-name': 'ietf-netconf-acm',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'tailf-aaa-1-system-security-admin',
#        'action': 'permit',
#        'module-name': 'tailf-aaa',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'tailf-acm-1-system-security-admin',
#        'path': '/nacm/tacm:cmd-read-default',
#        'action': 'deny',
#        'module-name': 'tailf-acm',
#        'access-operations': 'create update delete exec',
#        'tailf-acm:context': '*'},
#       {'name': 'tailf-acm-2-system-security-admin',
#        'path': '/nacm/tacm:cmd-exec-default',
#        'action': 'deny',
#        'module-name': 'tailf-acm',
#        'access-operations': 'create update delete exec',
#        'tailf-acm:context': '*'},
#       {'name': 'tailf-acm-3-system-security-admin',
#        'path': '/nacm/tacm:log-if-default-permit',
#        'action': 'deny',
#        'module-name': 'tailf-acm',
#        'access-operations': 'create update delete exec',
#        'tailf-acm:context': '*'},
#       {'name': 'tailf-acm-4-system-security-admin',
#        'action': 'permit',
#        'module-name': 'tailf-acm',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-1-system-security-admin-lock',
#        'action': 'permit',
#        'rpc-name': 'lock',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-2-system-security-admin-unlock',
#        'action': 'permit',
#        'rpc-name': 'unlock',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-3-system-security-admin-kill-session',
#        'action': 'permit',
#        'rpc-name': 'kill-session',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'}],
#      'group': ['system-security-admin'],
#      'tailf-acm:cmdrule': [{'name': 'show-alarm-cmd',
#        'action': 'deny',
#        'command': 'show alarm',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-alarm-history-cmd',
#        'action': 'deny',
#        'command': 'show alarm-history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'nacm-cmd',
#        'action': 'permit',
#        'command': 'nacm',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'xxload-cmd',
#        'action': 'permit',
#        'command': 'xxload',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'session-cmd',
#        'action': 'permit',
#        'command': 'session',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'user-cmd',
#        'action': 'permit',
#        'command': 'user',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'alias-cmd',
#        'action': 'permit',
#        'command': 'alias',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'autowizard-cmd',
#        'action': 'permit',
#        'command': 'autowizard',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'change-password-cmd',
#        'action': 'permit',
#        'command': 'change-password',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'clear-cmd',
#        'action': 'permit',
#        'command': 'clear',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'complete-on-space-cmd',
#        'action': 'permit',
#        'command': 'complete-on-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'describe-cmd',
#        'action': 'permit',
#        'command': 'describe',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-level-cmd',
#        'action': 'permit',
#        'command': 'display-level',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'quit-cmd',
#        'action': 'permit',
#        'command': 'quit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'help-cmd',
#        'action': 'permit',
#        'command': 'help',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'history-cmd',
#        'action': 'permit',
#        'command': 'history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'idle-timeout-cmd',
#        'action': 'permit',
#        'command': 'idle-timeout',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'ignore-leading-space-cmd',
#        'action': 'permit',
#        'command': 'ignore-leading-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'leaf-prompting-cmd',
#        'action': 'permit',
#        'command': 'leaf-prompting',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'no-cmd',
#        'action': 'permit',
#        'command': 'no',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'paginate-cmd',
#        'action': 'permit',
#        'command': 'paginate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'pwd-cmd',
#        'action': 'permit',
#        'command': 'pwd',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-length-cmd',
#        'action': 'permit',
#        'command': 'screen-length',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-width-cmd',
#        'action': 'permit',
#        'command': 'screen-width',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'timestamp-cmd',
#        'action': 'permit',
#        'command': 'timestamp',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'config-cmd',
#        'action': 'permit',
#        'command': 'config',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'abort-cmd',
#        'action': 'permit',
#        'command': 'abort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'commit-cmd',
#        'action': 'permit',
#        'command': 'commit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'compare-cmd',
#        'action': 'permit',
#        'command': 'compare',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'do-cmd',
#        'action': 'permit',
#        'command': 'do',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'end-cmd',
#        'action': 'permit',
#        'command': 'end',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'file-cmd',
#        'action': 'permit',
#        'command': 'file',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'insert-cmd',
#        'action': 'permit',
#        'command': 'insert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'load-cmd',
#        'action': 'permit',
#        'command': 'load',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'move-cmd',
#        'action': 'permit',
#        'command': 'move',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rename-cmd',
#        'action': 'permit',
#        'command': 'rename',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'resolved-cmd',
#        'action': 'permit',
#        'command': 'resolved',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'revert-cmd',
#        'action': 'permit',
#        'command': 'revert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'top-cmd',
#        'action': 'permit',
#        'command': 'top',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'validate-cmd',
#        'action': 'permit',
#        'command': 'validate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-cmd',
#        'action': 'permit',
#        'command': 'show',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rollback-cmd',
#        'action': 'permit',
#        'command': 'rollback',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'save-cmd',
#        'action': 'permit',
#        'command': 'save',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-cmd',
#        'action': 'permit',
#        'command': 'display',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'begin-cmd',
#        'action': 'permit',
#        'command': 'begin',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'best-effort-cmd',
#        'action': 'permit',
#        'command': 'best-effort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'context-match-cmd',
#        'action': 'permit',
#        'command': 'context-match',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'count-cmd',
#        'action': 'permit',
#        'command': 'count',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'csv-cmd',
#        'action': 'permit',
#        'command': 'csv',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'debug-cmd',
#        'action': 'permit',
#        'command': 'debug',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'de-select-cmd',
#        'action': 'permit',
#        'command': 'de-select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'details-cmd',
#        'action': 'permit',
#        'command': 'details',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'exclude-cmd',
#        'action': 'permit',
#        'command': 'exclude',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'extended-cmd',
#        'action': 'permit',
#        'command': 'extended',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'include-cmd',
#        'action': 'permit',
#        'command': 'include',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'linnum-cmd',
#        'action': 'permit',
#        'command': 'linnum',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-all-cmd',
#        'action': 'permit',
#        'command': 'match-all',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-any-cmd',
#        'action': 'permit',
#        'command': 'match-any',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'more-cmd',
#        'action': 'permit',
#        'command': 'more',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'nomore-cmd',
#        'action': 'permit',
#        'command': 'nomore',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'select-cmd',
#        'action': 'permit',
#        'command': 'select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'sort-by-cmd',
#        'action': 'permit',
#        'command': 'sort-by',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'suppress-validate-warning-prompt-cmd',
#        'action': 'permit',
#        'command': 'suppress-validate-warning-prompt',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'tab-cmd',
#        'action': 'permit',
#        'command': 'tab',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'until-cmd',
#        'action': 'permit',
#        'command': 'until',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-defaults-cmd',
#        'action': 'permit',
#        'command': 'show-defaults',
#        'context': 'cli',
#        'access-operations': '*'}]},
#     {'name': 'ericsson-cm-yang-provider-3-system-read-only',
#      'rule': [{'name': 'tailf-confd_dyncfg-1-system-read-only',
#        'action': 'permit',
#        'module-name': 'confd_dyncfg',
#        'access-operations': 'read',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-1-system-read-only',
#        'action': 'permit',
#        'module-name': 'ietf-netconf',
#        'access-operations': 'read',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-notifications-1-system-read-only',
#        'action': 'permit',
#        'module-name': 'ietf-netconf-notifications',
#        'access-operations': 'read',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-monitoring-1-system-read-only',
#        'action': 'permit',
#        'module-name': 'ietf-netconf-monitoring',
#        'access-operations': 'read',
#        'tailf-acm:context': '*'}],
#      'group': ['system-read-only'],
#      'tailf-acm:cmdrule': [{'name': 'show-alarm-cmd',
#        'action': 'deny',
#        'command': 'show alarm',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-alarm-history-cmd',
#        'action': 'deny',
#        'command': 'show alarm-history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'aaa-cmd',
#        'action': 'permit',
#        'command': 'aaa',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'xxload-cmd',
#        'action': 'permit',
#        'command': 'xxload',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'user-cmd',
#        'action': 'permit',
#        'command': 'user',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'autowizard-cmd',
#        'action': 'permit',
#        'command': 'autowizard',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'change-password-cmd',
#        'action': 'permit',
#        'command': 'change-password',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'clear-cmd',
#        'action': 'permit',
#        'command': 'clear',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'complete-on-space-cmd',
#        'action': 'permit',
#        'command': 'complete-on-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'describe-cmd',
#        'action': 'permit',
#        'command': 'describe',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-level-cmd',
#        'action': 'permit',
#        'command': 'display-level',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'quit-cmd',
#        'action': 'permit',
#        'command': 'quit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'help-cmd',
#        'action': 'permit',
#        'command': 'help',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'history-cmd',
#        'action': 'permit',
#        'command': 'history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'idle-timeout-cmd',
#        'action': 'permit',
#        'command': 'idle-timeout',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'ignore-leading-space-cmd',
#        'action': 'permit',
#        'command': 'ignore-leading-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'leaf-prompting-cmd',
#        'action': 'permit',
#        'command': 'leaf-prompting',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'no-cmd',
#        'action': 'permit',
#        'command': 'no',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'paginate-cmd',
#        'action': 'permit',
#        'command': 'paginate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'pwd-cmd',
#        'action': 'permit',
#        'command': 'pwd',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-length-cmd',
#        'action': 'permit',
#        'command': 'screen-length',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-width-cmd',
#        'action': 'permit',
#        'command': 'screen-width',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'timestamp-cmd',
#        'action': 'permit',
#        'command': 'timestamp',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'config-cmd',
#        'action': 'permit',
#        'command': 'config',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'abort-cmd',
#        'action': 'permit',
#        'command': 'abort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'commit-cmd',
#        'action': 'permit',
#        'command': 'commit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'compare-cmd',
#        'action': 'permit',
#        'command': 'compare',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'do-cmd',
#        'action': 'permit',
#        'command': 'do',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'end-cmd',
#        'action': 'permit',
#        'command': 'end',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'file-cmd',
#        'action': 'permit',
#        'command': 'file',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'insert-cmd',
#        'action': 'permit',
#        'command': 'insert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'load-cmd',
#        'action': 'permit',
#        'command': 'load',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'move-cmd',
#        'action': 'permit',
#        'command': 'move',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rename-cmd',
#        'action': 'permit',
#        'command': 'rename',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'resolved-cmd',
#        'action': 'permit',
#        'command': 'resolved',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'revert-cmd',
#        'action': 'permit',
#        'command': 'revert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'top-cmd',
#        'action': 'permit',
#        'command': 'top',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'validate-cmd',
#        'action': 'permit',
#        'command': 'validate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-cmd',
#        'action': 'permit',
#        'command': 'show',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rollback-cmd',
#        'action': 'permit',
#        'command': 'rollback',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'save-cmd',
#        'action': 'permit',
#        'command': 'save',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-cmd',
#        'action': 'permit',
#        'command': 'display',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'begin-cmd',
#        'action': 'permit',
#        'command': 'begin',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'best-effort-cmd',
#        'action': 'permit',
#        'command': 'best-effort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'context-match-cmd',
#        'action': 'permit',
#        'command': 'context-match',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'count-cmd',
#        'action': 'permit',
#        'command': 'count',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'csv-cmd',
#        'action': 'permit',
#        'command': 'csv',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'debug-cmd',
#        'action': 'permit',
#        'command': 'debug',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'de-select-cmd',
#        'action': 'permit',
#        'command': 'de-select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'details-cmd',
#        'action': 'permit',
#        'command': 'details',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'exclude-cmd',
#        'action': 'permit',
#        'command': 'exclude',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'extended-cmd',
#        'action': 'permit',
#        'command': 'extended',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'include-cmd',
#        'action': 'permit',
#        'command': 'include',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'linnum-cmd',
#        'action': 'permit',
#        'command': 'linnum',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-all-cmd',
#        'action': 'permit',
#        'command': 'match-all',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-any-cmd',
#        'action': 'permit',
#        'command': 'match-any',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'more-cmd',
#        'action': 'permit',
#        'command': 'more',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'nomore-cmd',
#        'action': 'permit',
#        'command': 'nomore',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'select-cmd',
#        'action': 'permit',
#        'command': 'select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'sort-by-cmd',
#        'action': 'permit',
#        'command': 'sort-by',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'suppress-validate-warning-prompt-cmd',
#        'action': 'permit',
#        'command': 'suppress-validate-warning-prompt',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'tab-cmd',
#        'action': 'permit',
#        'command': 'tab',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'until-cmd',
#        'action': 'permit',
#        'command': 'until',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-defaults-cmd',
#        'action': 'permit',
#        'command': 'show-defaults',
#        'context': 'cli',
#        'access-operations': '*'}]},
#     {'name': 'ericsson-cm-yang-provider-5-system-privacy-operator',
#      'rule': [{'name': 'tailf-aaa-authentication-5-system-privacy-operator',
#        'path': '/alias',
#        'action': 'permit',
#        'module-name': 'tailf-aaa',
#        'access-operations': '*',
#        'tailf-acm:context': '*'}],
#      'group': ['system-privacy-operator'],
#      'tailf-acm:cmdrule': [{'name': 'show-alarm-cmd',
#        'action': 'deny',
#        'command': 'show alarm',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-alarm-history-cmd',
#        'action': 'deny',
#        'command': 'show alarm-history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'xxload-cmd',
#        'action': 'permit',
#        'command': 'xxload',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'autowizard-cmd',
#        'action': 'permit',
#        'command': 'autowizard',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'change-password-cmd',
#        'action': 'permit',
#        'command': 'change-password',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'clear-cmd',
#        'action': 'permit',
#        'command': 'clear',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'complete-on-space-cmd',
#        'action': 'permit',
#        'command': 'complete-on-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'describe-cmd',
#        'action': 'permit',
#        'command': 'describe',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-level-cmd',
#        'action': 'permit',
#        'command': 'display-level',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'quit-cmd',
#        'action': 'permit',
#        'command': 'quit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'help-cmd',
#        'action': 'permit',
#        'command': 'help',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'history-cmd',
#        'action': 'permit',
#        'command': 'history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'idle-timeout-cmd',
#        'action': 'permit',
#        'command': 'idle-timeout',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'ignore-leading-space-cmd',
#        'action': 'permit',
#        'command': 'ignore-leading-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'leaf-prompting-cmd',
#        'action': 'permit',
#        'command': 'leaf-prompting',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'no-cmd',
#        'action': 'permit',
#        'command': 'no',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'paginate-cmd',
#        'action': 'permit',
#        'command': 'paginate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'pwd-cmd',
#        'action': 'permit',
#        'command': 'pwd',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-length-cmd',
#        'action': 'permit',
#        'command': 'screen-length',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-width-cmd',
#        'action': 'permit',
#        'command': 'screen-width',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'timestamp-cmd',
#        'action': 'permit',
#        'command': 'timestamp',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'config-cmd',
#        'action': 'permit',
#        'command': 'config',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'abort-cmd',
#        'action': 'permit',
#        'command': 'abort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'commit-cmd',
#        'action': 'permit',
#        'command': 'commit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'compare-cmd',
#        'action': 'permit',
#        'command': 'compare',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'do-cmd',
#        'action': 'permit',
#        'command': 'do',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'end-cmd',
#        'action': 'permit',
#        'command': 'end',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'file-cmd',
#        'action': 'permit',
#        'command': 'file',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'insert-cmd',
#        'action': 'permit',
#        'command': 'insert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'load-cmd',
#        'action': 'permit',
#        'command': 'load',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'move-cmd',
#        'action': 'permit',
#        'command': 'move',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rename-cmd',
#        'action': 'permit',
#        'command': 'rename',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'resolved-cmd',
#        'action': 'permit',
#        'command': 'resolved',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'revert-cmd',
#        'action': 'permit',
#        'command': 'revert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'top-cmd',
#        'action': 'permit',
#        'command': 'top',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'validate-cmd',
#        'action': 'permit',
#        'command': 'validate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-cmd',
#        'action': 'permit',
#        'command': 'show',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rollback-cmd',
#        'action': 'permit',
#        'command': 'rollback',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'save-cmd',
#        'action': 'permit',
#        'command': 'save',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-cmd',
#        'action': 'permit',
#        'command': 'display',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'begin-cmd',
#        'action': 'permit',
#        'command': 'begin',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'best-effort-cmd',
#        'action': 'permit',
#        'command': 'best-effort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'context-match-cmd',
#        'action': 'permit',
#        'command': 'context-match',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'count-cmd',
#        'action': 'permit',
#        'command': 'count',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'csv-cmd',
#        'action': 'permit',
#        'command': 'csv',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'debug-cmd',
#        'action': 'permit',
#        'command': 'debug',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'de-select-cmd',
#        'action': 'permit',
#        'command': 'de-select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'details-cmd',
#        'action': 'permit',
#        'command': 'details',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'exclude-cmd',
#        'action': 'permit',
#        'command': 'exclude',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'extended-cmd',
#        'action': 'permit',
#        'command': 'extended',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'include-cmd',
#        'action': 'permit',
#        'command': 'include',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'linnum-cmd',
#        'action': 'permit',
#        'command': 'linnum',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-all-cmd',
#        'action': 'permit',
#        'command': 'match-all',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-any-cmd',
#        'action': 'permit',
#        'command': 'match-any',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'more-cmd',
#        'action': 'permit',
#        'command': 'more',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'nomore-cmd',
#        'action': 'permit',
#        'command': 'nomore',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'select-cmd',
#        'action': 'permit',
#        'command': 'select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'sort-by-cmd',
#        'action': 'permit',
#        'command': 'sort-by',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'suppress-validate-warning-prompt-cmd',
#        'action': 'permit',
#        'command': 'suppress-validate-warning-prompt',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'tab-cmd',
#        'action': 'permit',
#        'command': 'tab',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'until-cmd',
#        'action': 'permit',
#        'command': 'until',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-defaults-cmd',
#        'action': 'permit',
#        'command': 'show-defaults',
#        'context': 'cli',
#        'access-operations': '*'}]},
#     {'name': 'ericsson-cm-yang-provider-6-system-privacy-admin',
#      'rule': [],
#      'group': ['system-privacy-admin'],
#      'tailf-acm:cmdrule': [{'name': 'show-alarm-cmd',
#        'action': 'deny',
#        'command': 'show alarm',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-alarm-history-cmd',
#        'action': 'deny',
#        'command': 'show alarm-history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'xxload-cmd',
#        'action': 'permit',
#        'command': 'xxload',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'alias-cmd',
#        'action': 'permit',
#        'command': 'alias',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'autowizard-cmd',
#        'action': 'permit',
#        'command': 'autowizard',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'change-password-cmd',
#        'action': 'permit',
#        'command': 'change-password',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'clear-cmd',
#        'action': 'permit',
#        'command': 'clear',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'complete-on-space-cmd',
#        'action': 'permit',
#        'command': 'complete-on-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'describe-cmd',
#        'action': 'permit',
#        'command': 'describe',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-level-cmd',
#        'action': 'permit',
#        'command': 'display-level',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'quit-cmd',
#        'action': 'permit',
#        'command': 'quit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'help-cmd',
#        'action': 'permit',
#        'command': 'help',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'history-cmd',
#        'action': 'permit',
#        'command': 'history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'idle-timeout-cmd',
#        'action': 'permit',
#        'command': 'idle-timeout',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'ignore-leading-space-cmd',
#        'action': 'permit',
#        'command': 'ignore-leading-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'leaf-prompting-cmd',
#        'action': 'permit',
#        'command': 'leaf-prompting',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'no-cmd',
#        'action': 'permit',
#        'command': 'no',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'paginate-cmd',
#        'action': 'permit',
#        'command': 'paginate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'pwd-cmd',
#        'action': 'permit',
#        'command': 'pwd',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-length-cmd',
#        'action': 'permit',
#        'command': 'screen-length',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-width-cmd',
#        'action': 'permit',
#        'command': 'screen-width',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'timestamp-cmd',
#        'action': 'permit',
#        'command': 'timestamp',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'config-cmd',
#        'action': 'permit',
#        'command': 'config',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'abort-cmd',
#        'action': 'permit',
#        'command': 'abort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'commit-cmd',
#        'action': 'permit',
#        'command': 'commit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'compare-cmd',
#        'action': 'permit',
#        'command': 'compare',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'do-cmd',
#        'action': 'permit',
#        'command': 'do',
#        'context': 'cli',
#        'access-operations': '*'},
# ...
#        'command': 'match-any',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'more-cmd',
#        'action': 'permit',
#        'command': 'more',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'nomore-cmd',
#        'action': 'permit',
#        'command': 'nomore',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'select-cmd',
#        'action': 'permit',
#        'command': 'select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'sort-by-cmd',
#        'action': 'permit',
#        'command': 'sort-by',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'suppress-validate-warning-prompt-cmd',
#        'action': 'permit',
#        'command': 'suppress-validate-warning-prompt',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'tab-cmd',
#        'action': 'permit',
#        'command': 'tab',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'until-cmd',
#        'action': 'permit',
#        'command': 'until',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-defaults-cmd',
#        'action': 'permit',
#        'command': 'show-defaults',
#        'context': 'cli',
#        'access-operations': '*'}]},
#     {'name': 'ericsson-cm-yang-provider-4-any-group',
#      'rule': [{'name': 'netconf_netmod-1-AnyGroup',
#        'path': '/netconf',
#        'action': 'permit',
#        'module-name': 'netconf_netmod',
#        'access-operations': 'read',
#        'tailf-acm:context': '*'},
#       {'name': 'ietf-netconf-1-AnyGroup-get',
#        'action': 'permit',
#        'rpc-name': 'get',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-2-AnyGroup-get-config',
#        'action': 'permit',
#        'rpc-name': 'get-config',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-3-AnyGroup-edit-config',
#        'action': 'permit',
#        'rpc-name': 'edit-config',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'no-model-1-AnyGroup-create-subscription',
#        'action': 'permit',
#        'rpc-name': 'create-subscription',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'no-model-1-AnyGroup-action',
#        'action': 'permit',
#        'rpc-name': 'action',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-4-AnyGroup-commit',
#        'action': 'permit',
#        'rpc-name': 'commit',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-5-AnyGroup-validate',
#        'action': 'permit',
#        'rpc-name': 'validate',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-6-AnyGroup-discard-changes',
#        'action': 'permit',
#        'rpc-name': 'discard-changes',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-7-AnyGroup-cancel-commit',
#        'action': 'permit',
#        'rpc-name': 'cancel-commit',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-netconf-monitoring-1-AnyGroup-get-schema',
#        'action': 'permit',
#        'rpc-name': 'get-schema',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-query-1-AnyGroup-start-query',
#        'action': 'permit',
#        'rpc-name': 'start-query',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-query-2-AnyGroup-fetch-query-result',
#        'action': 'permit',
#        'rpc-name': 'fetch-query-result',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-query-3-AnyGroup-immediate-query',
#        'action': 'permit',
#        'rpc-name': 'immediate-query',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-query-4-AnyGroup-reset-query',
#        'action': 'permit',
#        'rpc-name': 'reset-query',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-query-5-AnyGroup-stop-query',
#        'action': 'permit',
#        'rpc-name': 'stop-query',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-transactions-1-AnyGroup-start-transaction',
#        'action': 'permit',
#        'rpc-name': 'start-transaction',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-transactions-2-AnyGroup-prepare-transaction',
#        'action': 'permit',
#        'rpc-name': 'prepare-transaction',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-transactions-3-AnyGroup-commit-transaction',
#        'action': 'permit',
#        'rpc-name': 'commit-transaction',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'tailf-netconf-transactions-4-AnyGroup-abort-transaction',
#        'action': 'permit',
#        'rpc-name': 'abort-transaction',
#        'module-name': '*',
#        'access-operations': 'exec',
#        'tailf-acm:context': 'netconf'},
#       {'name': 'ietf-yang-library-rule-1-AnyGroup',
#        'action': 'permit',
#        'module-name': 'ietf-yang-library',
#        'access-operations': '*',
#        'tailf-acm:context': '*'},
#       {'name': 'ericsson-yang-library-ext-1-AnyGroup',
#        'action': 'permit',
#        'module-name': 'ericsson-yang-library-ext',
#        'access-operations': '*',
#        'tailf-acm:context': '*'}],
#      'group': ['*'],
#      'tailf-acm:cmdrule': [{'name': 'show-alarm-cmd',
#        'action': 'deny',
#        'command': 'show alarm',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-alarm-history-cmd',
#        'action': 'deny',
#        'command': 'show alarm-history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'aaa-cmd',
#        'action': 'permit',
#        'command': 'aaa',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'xxload-cmd',
#        'action': 'permit',
#        'command': 'xxload',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'user-cmd',
#        'action': 'permit',
#        'command': 'user',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'autowizard-cmd',
#        'action': 'permit',
#        'command': 'autowizard',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'change-password-cmd',
#        'action': 'permit',
#        'command': 'change-password',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'clear-cmd',
#        'action': 'permit',
#        'command': 'clear',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'complete-on-space-cmd',
#        'action': 'permit',
#        'command': 'complete-on-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'describe-cmd',
#        'action': 'permit',
#        'command': 'describe',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-level-cmd',
#        'action': 'permit',
#        'command': 'display-level',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'quit-cmd',
#        'action': 'permit',
#        'command': 'quit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'help-cmd',
#        'action': 'permit',
#        'command': 'help',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'history-cmd',
#        'action': 'permit',
#        'command': 'history',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'idle-timeout-cmd',
#        'action': 'permit',
#        'command': 'idle-timeout',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'ignore-leading-space-cmd',
#        'action': 'permit',
#        'command': 'ignore-leading-space',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'leaf-prompting-cmd',
#        'action': 'permit',
#        'command': 'leaf-prompting',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'no-cmd',
#        'action': 'permit',
#        'command': 'no',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'paginate-cmd',
#        'action': 'permit',
#        'command': 'paginate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'pwd-cmd',
#        'action': 'permit',
#        'command': 'pwd',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-length-cmd',
#        'action': 'permit',
#        'command': 'screen-length',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'screen-width-cmd',
#        'action': 'permit',
#        'command': 'screen-width',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'timestamp-cmd',
#        'action': 'permit',
#        'command': 'timestamp',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'config-cmd',
#        'action': 'permit',
#        'command': 'config',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'abort-cmd',
#        'action': 'permit',
#        'command': 'abort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'commit-cmd',
#        'action': 'permit',
#        'command': 'commit',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'compare-cmd',
#        'action': 'permit',
#        'command': 'compare',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'do-cmd',
#        'action': 'permit',
#        'command': 'do',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'end-cmd',
#        'action': 'permit',
#        'command': 'end',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'file-cmd',
#        'action': 'permit',
#        'command': 'file',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'insert-cmd',
#        'action': 'permit',
#        'command': 'insert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'load-cmd',
#        'action': 'permit',
#        'command': 'load',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'move-cmd',
#        'action': 'permit',
#        'command': 'move',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rename-cmd',
#        'action': 'permit',
#        'command': 'rename',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'resolved-cmd',
#        'action': 'permit',
#        'command': 'resolved',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'revert-cmd',
#        'action': 'permit',
#        'command': 'revert',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'top-cmd',
#        'action': 'permit',
#        'command': 'top',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'validate-cmd',
#        'action': 'permit',
#        'command': 'validate',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-cmd',
#        'action': 'permit',
#        'command': 'show',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'rollback-cmd',
#        'action': 'permit',
#        'command': 'rollback',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'save-cmd',
#        'action': 'permit',
#        'command': 'save',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'display-cmd',
#        'action': 'permit',
#        'command': 'display',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'begin-cmd',
#        'action': 'permit',
#        'command': 'begin',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'best-effort-cmd',
#        'action': 'permit',
#        'command': 'best-effort',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'context-match-cmd',
#        'action': 'permit',
#        'command': 'context-match',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'count-cmd',
#        'action': 'permit',
#        'command': 'count',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'csv-cmd',
#        'action': 'permit',
#        'command': 'csv',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'debug-cmd',
#        'action': 'permit',
#        'command': 'debug',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'de-select-cmd',
#        'action': 'permit',
#        'command': 'de-select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'details-cmd',
#        'action': 'permit',
#        'command': 'details',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'exclude-cmd',
#        'action': 'permit',
#        'command': 'exclude',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'extended-cmd',
#        'action': 'permit',
#        'command': 'extended',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'include-cmd',
#        'action': 'permit',
#        'command': 'include',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'linnum-cmd',
#        'action': 'permit',
#        'command': 'linnum',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-all-cmd',
#        'action': 'permit',
#        'command': 'match-all',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'match-any-cmd',
#        'action': 'permit',
#        'command': 'match-any',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'more-cmd',
#        'action': 'permit',
#        'command': 'more',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'nomore-cmd',
#        'action': 'permit',
#        'command': 'nomore',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'select-cmd',
#        'action': 'permit',
#        'command': 'select',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'sort-by-cmd',
#        'action': 'permit',
#        'command': 'sort-by',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'suppress-validate-warning-prompt-cmd',
#        'action': 'permit',
#        'command': 'suppress-validate-warning-prompt',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'tab-cmd',
#        'action': 'permit',
#        'command': 'tab',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'until-cmd',
#        'action': 'permit',
#        'command': 'until',
#        'context': 'cli',
#        'access-operations': '*'},
#       {'name': 'show-defaults-cmd',
#        'action': 'permit',
#        'command': 'show-defaults',
#        'context': 'cli',
#        'access-operations': '*'}]}],
#    'enable-nacm': True,
#    'exec-default': 'deny',
#    'read-default': 'deny',
#    'write-default': 'deny',
#    'denied-operations': 0,
#    'denied-data-writes': 0,
#    'denied-notifications': 0,
#    'enable-external-groups': True,
#    'tailf-acm:cmd-exec-default': 'deny',
#    'tailf-acm:cmd-read-default': 'deny'}}}

# %%
result
# Out:
# <Response [200]>

# %%
import json

# %%
ericsson_brm = json.loads(result.text)

# %%
ericsson_brm = result.json()

# %%
brms = ericsson_brm['data']['ericsson-brm:brm']['backup-manager']

# %%
for brm in brms:
    if brm['id'] == "DEFAULT":
        print(brm)
        break
# Out:
# {'id': 'DEFAULT', 'backup': [{'id': 'bu43', 'status': 'backup-complete', 'sw-version': [{'type': 'Database', 'description': 'eric-data-document-database-pg Agent for backup and restore.', 'product-name': 'Document Database PG', 'product-number': 'APR 201 34', 'production-date': '2022-09-06T20:32:15.638618Z', 'product-revision': '8.0.0-81'}, {'type': 'Predelivery', 'description': 'Test Application Drop 15', 'product-name': 'Test Application', 'product-number': 'APR XXX XX/X', 'production-date': '2019-05-17T14:12:44+00:00', 'product-revision': 'R1A'}], 'backup-name': 'bu43', 'creation-time': '2022-09-06T20:16:49.149101Z', 'creation-type': 'manual', 'progress-report': []}, {'id': 'bu45', 'status': 'backup-complete', 'sw-version': [{'type': 'Database', 'description': 'eric-data-document-database-pg Agent for backup and restore.', 'product-name': 'Document Database PG', 'product-number': 'APR 201 34', 'production-date': '2022-09-06T20:32:15.640815Z', 'product-revision': '8.0.0-81'}, {'type': 'Predelivery', 'description': 'Test Application Drop 15', 'product-name': 'Test Application', 'product-number': 'APR XXX XX/X', 'production-date': '2019-05-17T14:12:44+00:00', 'product-revision': 'R1A'}], 'backup-name': 'bu45', 'creation-time': '2022-09-06T20:30:01.004843Z', 'creation-type': 'manual', 'progress-report': [{'state': 'finished', 'result': 'success', 'action-id': 50971, 'action-name': 'RESTORE', 'result-info': '{Agent: eric-data-document-database-pg, Stage: PREPARATION, success: true, message: Preparation for restore is successful}, {Agent: eric-data-document-database-pg, Stage: EXECUTION, success: true, message: bu45 restore complete.}, {Agent: eric-data-document-database-pg, Stage: POST_ACTIONS, success: true, message: Post restore actions completed}', 'additional-info': [], 'progress-percentage': 100, 'time-action-started': '2022-09-06T20:31:24.415642Z', 'time-action-completed': '2022-09-06T20:32:15.715622Z', 'time-of-last-status-update': '2022-09-06T20:32:15.715622Z'}]}], 'scheduler': {'admin-state': 'unlocked', 'auto-export': 'disabled', 'periodic-event': [], 'progress-report': [], 'scheduled-backup-name': 'SCHEDULED_BACKUP'}, 'backup-type': '', 'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 123}, 'backup-domain': '', 'progress-report': [{'state': 'finished', 'result': 'success', 'action-id': 5529, 'action-name': 'CREATE_BACKUP', 'result-info': '{Agent: eric-data-document-database-pg, Stage: PREPARATION, success: true, message: Preparation for backup is successful}, {Agent: eric-data-document-database-pg, Stage: EXECUTION, success: true, message: The PG B&R Agent has completed a backup for bu45}, {Agent: eric-data-document-database-pg, Stage: POST_ACTIONS, success: true, message: Post backup actions completed}', 'additional-info': [], 'progress-percentage': 100, 'time-action-started': '2022-09-06T20:29:59.960302Z', 'time-action-completed': '2022-09-06T20:30:12.069152Z', 'time-of-last-status-update': '2022-09-06T20:30:12.069152Z'}]}

# %%
url = f'{baseurl}/cm/api/v1/configurations/ericsson-brm:brm/backup-manager/1/backup'
result = requests.get(url)
result.json()
# Out:
# {'message': 'URL path not found on server'}

# %%
object['data']['ericsson-brm:brm']['backup-manager']
# Out:
# [{'id': 'DEFAULT-eric-data-document-database-pg',
#   'backup': [],
#   'scheduler': {'admin-state': 'unlocked',
#    'auto-export': 'disabled',
#    'periodic-event': [],
#    'progress-report': [],
#    'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#   'backup-type': '',
#   'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 1},
#   'backup-domain': '',
#   'progress-report': []},
#  {'id': 'DEFAULT',
#   'backup': [],
#   'scheduler': {'admin-state': 'unlocked',
#    'auto-export': 'disabled',
#    'periodic-event': [],
#    'progress-report': [],
#    'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#   'backup-type': '',
#   'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 3},
#   'backup-domain': '',
#   'progress-report': []},
#  {'id': 'DEFAULT-tls',
#   'backup': [],
#   'scheduler': {'admin-state': 'unlocked',
#    'auto-export': 'disabled',
#    'periodic-event': [],
#    'progress-report': [],
#    'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#   'backup-type': '',
#   'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 1},
#   'backup-domain': '',
#   'progress-report': []},
#  {'id': 'configuration-data',
#   'backup': [{'id': 'backup_2',
#     'status': 'backup-complete',
#     'sw-version': [{'type': 'Database',
#       'description': 'eric-data-document-database-pg Agent for backup and restore.',
#       'product-name': 'Document Database PG',
#       'product-number': 'APR 201 34',
#       'production-date': '2022-03-23T12:10:35.811092Z',
#       'product-revision': '7.3.0-26'},
#      {'type': 'Legend',
#       'description': 'agent tls',
#       'product-name': 'Tiger',
#       'product-number': 'CXC 888 88/8',
#       'production-date': '2022-03-23T12:10:35.811154Z',
#       'product-revision': 'R15'},
#      {'type': 'data',
#       'description': 'test agent bravo',
#       'product-name': 'bravo',
#       'product-number': 'CXC 222 22/2',
#       'production-date': '2022-03-23T12:10:35.811221Z',
#       'product-revision': 'R2'},
#      {'type': 'Predelivery',
#       'description': 'Test Application Drop 15',
#       'product-name': 'Test Application',
#       'product-number': 'APR XXX XX/X',
#       'production-date': '2019-05-17T14:12:44+00:00',
#       'product-revision': 'R1A'}],
#     'backup-name': 'backup_2',
#     'creation-time': '2022-03-23T12:10:35.795867Z',
#     'creation-type': 'manual',
#     'progress-report': []}],
#   'scheduler': {'admin-state': 'unlocked',
#    'auto-export': 'disabled',
#    'periodic-event': [],
#    'progress-report': [],
#    'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#   'backup-type': '',
#   'housekeeping': {'auto-delete': 'disabled', 'max-stored-manual-backups': 1},
#   'backup-domain': '',
#   'progress-report': [{'state': 'finished',
#     'result': 'failure',
#     'action-id': 53798,
#     'action-name': 'IMPORT',
#     'additional-info': ['Failed to create/import backup as maximum limit of <1> already exceeded'],
#     'progress-percentage': 0,
#     'time-action-started': '2022-03-23T12:10:52.28532Z',
#     'time-action-completed': '2022-03-23T12:10:52.508912Z',
#     'time-of-last-status-update': '2022-03-23T12:10:52.508912Z'}]},
#  {'id': 'DEFAULT-bravo',
#   'backup': [],
#   'scheduler': {'admin-state': 'unlocked',
#    'auto-export': 'disabled',
#    'periodic-event': [],
#    'progress-report': [],
#    'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#   'backup-type': '',
#   'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 1},
#   'backup-domain': '',
#   'progress-report': []}]

# %%
object['data']['ericsson-brm:brm']['backup-manager'][0]
# Out:
# {'id': 'DEFAULT-eric-data-document-database-pg',
#  'backup': [],
#  'scheduler': {'admin-state': 'unlocked',
#   'auto-export': 'disabled',
#   'periodic-event': [],
#   'progress-report': [],
#   'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#  'backup-type': '',
#  'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 1},
#  'backup-domain': '',
#  'progress-report': []}

# %%
object['data']['ericsson-brm:brm']['backup-manager'][0]['id']
# Out:
# 'DEFAULT-eric-data-document-database-pg'

# %% [markdown]
# ### Using jsonpointer

# %% [markdown]
# #### Get brms

# %%
url = f'{baseurl}/cm/api/v1/configurations/ericsson-brm?jsonpointer=/ericsson-brm:brm'
result = requests.get(url)
result.json()
# Out:
# {'name': 'ericsson-brm',
#  'title': 'ericsson-brm',
#  'data': {'backup-manager': [{'id': 'DEFAULT-bro',
#     'backup': [],
#     'scheduler': {'admin-state': 'unlocked',
#      'auto-export': 'disabled',
#      'periodic-event': [],
#      'progress-report': [],
#      'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#     'backup-type': '',
#     'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 1},
#     'backup-domain': '',
#     'progress-report': []},
#    {'id': 'configuration-data-bro',
#     'backup': [{'id': 'bu49',
#       'status': 'backup-complete',
#       'sw-version': [{'type': 'Database',
#         'description': 'eric-data-document-database-pg Agent for backup and restore.',
#         'product-name': 'Document Database PG',
#         'product-number': 'APR 201 34',
#         'production-date': '2022-09-14T08:24:38.094824Z',
#         'product-revision': '8.0.0-96'},
#        {'type': 'Predelivery',
#         'description': 'Test Application Drop 15',
#         'product-name': 'Test Application',
#         'product-number': 'APR XXX XX/X',
#         'production-date': '2019-05-17T14:12:44+00:00',
#         'product-revision': 'R1A'}],
#       'backup-name': 'bu49',
#       'creation-time': '2022-09-14T08:24:37.987632Z',
#       'creation-type': 'manual',
#       'progress-report': []}],
#     'scheduler': {'admin-state': 'unlocked',
#      'auto-export': 'disabled',
#      'periodic-event': [],
#      'progress-report': [],
#      'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#     'backup-type': '',
#     'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 1},
#     'backup-domain': '',
#     'progress-report': []},
#    {'id': 'configuration-data',
#     'backup': [{'id': 'bu49',
#       'status': 'backup-complete',
#       'sw-version': [{'type': 'Database',
#         'description': 'eric-data-document-database-pg Agent for backup and restore.',
#         'product-name': 'Document Database PG',
#         'product-number': 'APR 201 34',
#         'production-date': '2022-09-14T08:24:38.047141Z',
#         'product-revision': '8.0.0-96'},
#        {'type': 'Predelivery',
#         'description': 'Test Application Drop 15',
#         'product-name': 'Test Application',
#         'product-number': 'APR XXX XX/X',
#         'production-date': '2019-05-17T14:12:44+00:00',
#         'product-revision': 'R1A'}],
#       'backup-name': 'bu49',
#       'creation-time': '2022-09-14T08:24:37.987632Z',
#       'creation-type': 'manual',
#       'progress-report': []}],
#     'scheduler': {'admin-state': 'unlocked',
#      'auto-export': 'disabled',
#      'periodic-event': [],
#      'progress-report': [],
#      'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#     'backup-type': '',
#     'housekeeping': {'auto-delete': 'enabled',
#      'max-stored-manual-backups': 164},
#     'backup-domain': '',
#     'progress-report': [{'state': 'finished',
#       'result': 'success',
#       'action-id': 48852,
#       'action-name': 'CREATE_BACKUP',
#       'result-info': '{Agent: eric-data-document-database-pg, Stage: PREPARATION, success: true, message: Preparation for backup is successful}, {Agent: eric-data-document-database-pg, Stage: EXECUTION, success: true, message: The PG B&R Agent has completed a backup for bu49}, {Agent: eric-data-document-database-pg, Stage: POST_ACTIONS, success: true, message: Post backup actions completed}',
#       'additional-info': [],
#       'progress-percentage': 100,
#       'time-action-started': '2022-09-14T08:24:36.617911Z',
#       'time-action-completed': '2022-09-14T08:24:57.942541Z',
#       'time-of-last-status-update': '2022-09-14T08:24:57.942541Z'}]},
#    {'id': 'DEFAULT',
#     'backup': [],
#     'scheduler': {'admin-state': 'unlocked',
#      'auto-export': 'disabled',
#      'periodic-event': [],
#      'progress-report': [],
#      'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#     'backup-type': '',
#     'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 1},
#     'backup-domain': '',
#     'progress-report': []}]}}

# %% [markdown]
# #### Get backups of the first brm

# %%
url = f'{baseurl}/cm/api/v1/configurations/ericsson-brm?jsonpointer=/ericsson-brm:brm/backup-manager/2'
result = requests.get(url)
result.json()
# Out:
# {'name': 'ericsson-brm',
#  'title': 'ericsson-brm',
#  'data': {'id': 'configuration-data',
#   'backup': [{'id': 'cmypBackup03',
#     'status': 'backup-complete',
#     'sw-version': [{'type': 'Database',
#       'description': 'eric-data-document-database-pg Agent for backup and restore.',
#       'product-name': 'Document Database PG',
#       'product-number': 'APR 201 34',
#       'production-date': '2022-09-07T13:54:57.685142Z',
#       'product-revision': '8.0.0-81'},
#      {'type': 'Predelivery',
#       'description': 'Test Application Drop 15',
#       'product-name': 'Test Application',
#       'product-number': 'APR XXX XX/X',
#       'production-date': '2019-05-17T14:12:44+00:00',
#       'product-revision': 'R1A'}],
#     'backup-name': 'cmypBackup03',
#     'creation-time': '2022-09-07T13:54:57.636651Z',
#     'creation-type': 'manual',
#     'progress-report': []}],
#   'scheduler': {'admin-state': 'unlocked',
#    'auto-export': 'disabled',
#    'periodic-event': [],
#    'progress-report': [],
#    'scheduled-backup-name': 'SCHEDULED_BACKUP'},
#   'backup-type': '',
#   'housekeeping': {'auto-delete': 'enabled', 'max-stored-manual-backups': 53},
#   'backup-domain': '',
#   'progress-report': [{'state': 'finished',
#     'result': 'success',
#     'action-id': 59559,
#     'action-name': 'CREATE_BACKUP',
#     'result-info': '{Agent: eric-data-document-database-pg, Stage: PREPARATION, success: true, message: Preparation for backup is successful}, {Agent: eric-data-document-database-pg, Stage: EXECUTION, success: true, message: The PG B&R Agent has completed a backup for cmypBackup03}, {Agent: eric-data-document-database-pg, Stage: POST_ACTIONS, success: true, message: Post backup actions completed}',
#     'additional-info': [],
#     'progress-percentage': 100,
#     'time-action-started': '2022-09-07T13:54:56.314996Z',
#     'time-action-completed': '2022-09-07T13:55:15.574011Z',
#     'time-of-last-status-update': '2022-09-07T13:55:15.574011Z'}]}}

# %%
url = f'{baseurl}/cm/api/v1/configurations/ericsson-brm?jsonpointer=/ericsson-brm:brm/backup-manager/1/backup/2'
result = requests.get(url)
result.json()
# Out:
# {'name': 'ericsson-brm',
#  'title': 'ericsson-brm',
#  'data': {'id': 'bu46',
#   'status': 'backup-complete',
#   'sw-version': [{'type': 'Database',
#     'description': 'eric-data-document-database-pg Agent for backup and restore.',
#     'product-name': 'Document Database PG',
#     'product-number': 'APR 201 34',
#     'production-date': '2022-09-06T20:43:31.934669Z',
#     'product-revision': '8.0.0-81'},
#    {'type': 'Predelivery',
#     'description': 'Test Application Drop 15',
#     'product-name': 'Test Application',
#     'product-number': 'APR XXX XX/X',
#     'production-date': '2019-05-17T14:12:44+00:00',
#     'product-revision': 'R1A'}],
#   'backup-name': 'bu46',
#   'creation-time': '2022-09-06T20:43:31.879943Z',
#   'creation-type': 'manual',
#   'progress-report': [{'state': 'finished',
#     'result': 'success',
#     'action-id': 38365,
#     'action-name': 'RESTORE',
#     'additional-info': [],
#     'progress-percentage': 100,
#     'time-action-started': '2022-09-06T20:44:42.467505Z',
#     'time-action-completed': '2022-09-06T20:44:43.639531Z',
#     'time-of-last-status-update': '2022-09-06T20:44:43.639531Z'}]}}

# %% [markdown]
# #### Get 1st backup of the 1st brm

# %%
url = f'{baseurl}/cm/api/v1/configurations/ericsson-brm?jsonpointer=/ericsson-brm:brm/backup-manager/0/backup/0'
result = requests.get(url)
result.json()
# Out:
# {'name': 'ericsson-brm',
#  'title': 'ericsson-brm',
#  'data': {'id': 'DemoBackup21',
#   'status': 'backup-complete',
#   'sw-version': [{'type': 'Database',
#     'description': 'eric-data-document-database-pg Agent for backup and restore.',
#     'product-name': 'Document Database PG',
#     'product-number': 'APR 201 34',
#     'production-date': '2022-02-17T14:44:03.782183Z',
#     'product-revision': '7.1.0-19'},
#    {'type': 'Predelivery',
#     'description': 'Test Application Drop 15',
#     'product-name': 'Test Application',
#     'product-number': 'APR XXX XX/X',
#     'production-date': '2019-05-17T14:12:44+00:00',
#     'product-revision': 'R1A'}],
#   'backup-name': 'DemoBackup21',
#   'creation-time': '2022-02-17T14:44:03.703133Z',
#   'creation-type': 'manual',
#   'progress-report': []}}

# %% [markdown]
# ### Using jsonpath query

# %%
url = f"{baseurl}/cm/api/v1/configurations/ericsson-brm?jsonpath='$..brm'"
result = requests.get(url)
result.json()
# Out:
# {'name': 'ericsson-brm', 'title': 'ericsson-brm', 'data': []}

# %% [markdown]
# ## Schema

# %% [markdown]
# ### List schemas

# %%
url = f'{baseurl}/cm/api/v1/schemas'
result = requests.get(url)
result.json()
# Out:
# [{'name': 'ietf-netconf-acm',
#   'title': 'CMYP Network Configuration Access Control Model'},
#  {'name': 'ericsson-brm', 'title': 'ericsson-brm'}]

# %% [markdown]
# ### Detail a schema

# %%
url = f'{baseurl}/cm/api/v1/schemas/ericsson-brm'
result = requests.get(url)
result.json()
# Out:
# {'name': 'ericsson-brm',
#  'title': 'ericsson-brm',
#  'jsonSchema': {'type': 'object',
#   'title': 'ericsson-brm',
#   '$schema': 'http://json-schema.org/draft-07/schema#',
#   'properties': {'ericsson-brm:brm': {'type': 'object',
#     'properties': {'backup-manager': {'type': 'array',
#       'items': {'type': 'object',
#        'required': ['backup-domain', 'backup-type', 'id'],
#        'properties': {'id': {'type': 'string',
#          'description': 'Identity of the backup-manager.'},
#         'backup': {'type': 'array',
#          'items': {'type': 'object',
#           'required': ['backup-name',
#            'creation-time',
#            'creation-type',
#            'id',
#            'status'],
#           'properties': {'id': {'type': 'string',
#             'description': 'Identity of the backup.'},
#            'status': {'enum': ['backup-complete',
#              'backup-incomplete',
#              'backup-corrupted'],
#             'description': 'Status of the backup.'},
#            'sw-version': {'type': 'array',
#             'items': {'type': 'object',
#              'required': ['description',
#               'product-name',
#               'product-number',
#               'product-revision',
#               'production-date',
#               'type'],
#              'properties': {'type': {'type': 'string',
#                'description': 'Free text description of the product type.'},
#               'description': {'type': 'string',
#                'description': 'Free text description of the product.'},
#               'product-name': {'type': 'string',
#                'description': 'Name of the product.'},
#               'product-number': {'type': 'string',
#                'description': 'Product number of the product.'},
#               'production-date': {'type': 'string',
#                'format': 'date-time',
#                'description': 'Production date of the product.'},
#               'product-revision': {'type': 'string',
#                'description': 'Revision state of the product.'}},
#              'additionalProperties': False},
#             'description': 'The administrative data portion of active software versions as specified in the software inventory management, when the backup is created.',
#             'uniqueItems': True},
#            'backup-name': {'type': 'string',
#             'description': 'Backup name, provided by the operator.'},
#            'creation-time': {'type': 'string',
#             'format': 'date-time',
#             'description': 'Date and time when the backup was created, i.e., start time of backup procedure.'},
#            'creation-type': {'enum': ['manual', 'scheduled', 'system-created'],
#             'description': 'Creation type; whether manually created or automatically via scheduler.'},
#            'progress-report': {'type': 'array',
#             'items': {'type': 'object',
#              'required': ['time-action-started', 'time-of-last-status-update'],
#              'properties': {'state': {'enum': ['cancelling',
#                 'running',
#                 'finished',
#                 'cancelled'],
#                'description': 'Current state of the action.'},
#               'result': {'enum': ['success', 'failure', 'not-available'],
#                'description': 'Result state of a completed action. This field has value not-available if the action is not finished.'},
#               'action-id': {'type': 'integer',
#                'format': 'uint16',
#                'maximum': 65535,
#                'minimum': 0,
#                'description': 'Uniquely identifies the invocation of an action. Identifies the invocation of an action when the managed object allows invocation of more than one action at a time.'},
#               'action-name': {'type': 'string',
#                'description': 'Name of the invoked asynchronous action.'},
#               'result-info': {'type': 'string',
#                'description': 'Textual description of the outcome/result of the action containing useful information for the NMS. If the action failed, it can contain an error message.'},
#               'progress-info': {'type': 'string',
#                'description': 'Textual information that describes the actual state of the action execution.'},
#               'additional-info': {'type': 'array',
#                'items': {'type': 'string'},
#                'description': 'Used for logging significant messages during execution of an action.'},
#               'progress-percentage': {'type': 'integer',
#                'format': 'uint8',
#                'maximum': 100,
#                'minimum': 0,
#                'description': 'Progress of the action.'},
#               'time-action-started': {'type': 'string',
#                'format': 'date-time',
#                'description': 'Date and time when the current action was started.'},
#               'time-action-completed': {'type': 'string',
#                'format': 'date-time',
#                'description': 'Date and time when the action was completed (successfully or unsuccessfully).'},
#               'time-of-last-status-update': {'type': 'string',
#                'format': 'date-time',
#                'description': 'Date and time when the struct member state was last updated.'}},
#              'additionalProperties': False},
#             'maxItems': 1,
#             'description': 'Represents the progress report and final result of the ongoing (asynchronous) action in this backup, for example restore. Backup supports only one action to be executed at a time.',
#             'uniqueItems': True}},
#           'additionalProperties': False},
#          'description': 'Represents one backup of the type and domain specified by the backup-manager in which it is contained.',
#          'uniqueItems': True,
#          'eric-adp-actions': ['ericsson-brm:brm::backup-manager::backup::restore',
#           'ericsson-brm:brm::backup-manager::backup::export']},
#         'scheduler': {'type': 'object',
#          'properties': {'admin-state': {'enum': ['locked', 'unlocked'],
#            'default': 'unlocked',
#            'description': 'Administrative state of the scheduler.'},
#           'auto-export': {'enum': ['enabled', 'disabled'],
#            'default': 'disabled',
#            'description': 'Determines whether a scheduled backup is to be automatically exported at successful creation. If set to ENABLED, the scheduled backup specified by the leaf most-recently-created-auto-backup is exported to the location specified by leaf auto-export-uri after it is successfully created. Note that the automatic export is only triggered if creation of the scheduled backup was successful. Otherwise, no export operation is triggered, even if this leaf is set to ENABLED. Also, note that setting this leaf to ENABLED has no impact on the scheduled backups that were already created and stored prior to the new configuration.'},
#           'periodic-event': {'type': 'array',
#            'items': {'type': 'object',
#             'required': ['hours', 'id'],
#             'properties': {'id': {'type': 'string',
#               'description': 'Identity of the periodic-event.'},
#              'days': {'type': 'integer',
#               'format': 'uint16',
#               'default': '0',
#               'maximum': 65535,
#               'minimum': 0,
#               'description': 'The number of days.'},
#              'hours': {'type': 'integer',
#               'format': 'uint16',
#               'maximum': 65535,
#               'minimum': 0,
#               'description': 'The number of hours.'},
#              'weeks': {'type': 'integer',
#               'format': 'uint16',
#               'default': '0',
#               'maximum': 65535,
#               'minimum': 0,
#               'description': 'The number of weeks.'},
#              'minutes': {'type': 'integer',
#               'format': 'uint16',
#               'default': '0',
#               'maximum': 65535,
#               'minimum': 0,
#               'description': 'The number of minutes.'},
#              'stop-time': {'type': 'string',
#               'format': 'date-time',
#               'description': 'Stop time. If no stop-time present the event continues indefinitely.'},
#              'start-time': {'type': 'string',
#               'format': 'date-time',
#               'description': 'Start time. If not specified, the implementation uses the current system time as the default value.'}},
#             'additionalProperties': False},
#            'description': 'Periodic backup event. This construct can be used to configure a periodic scheduled backup event by specifying the number of months, weeks, days, hours, or minutes. For instance, in order to configure a scheduled backup event to occur every 12 hours, the following setup must be done: hours = 12. If more than one leaf is set, the values are added when calculating the next scheduled event. For example, if hours = 6 and minutes = 30, the scheduled backup event occurs every 6 hour and 30 minutes. The start time for calculating scheduled events is assumed to be the current system time by default, unless explicitly set using the start-time leaf. Furthermore, if the configured event is to stop at a specific date, leaf stop-time must be set accordingly. Daylight saving adjustments in Spring and Fall are addressed in such a way that the affected scheduled backup events are triggered exactly once only',
#            'uniqueItems': True},
#           'auto-export-uri': {'type': 'string',
#            'format': 'uri',
#            'description': 'Uri used by the backup scheduler when automatically exporting a scheduled backup. If leaf auto-export is set to ENABLED, this uri specifies the location to which the scheduled backup is automatically exported.'},
#           'progress-report': {'type': 'array',
#            'items': {'type': 'object',
#             'required': ['time-action-started', 'time-of-last-status-update'],
#             'properties': {'state': {'enum': ['cancelling',
#                'running',
#                'finished',
#                'cancelled'],
#               'description': 'Current state of the action.'},
#              'result': {'enum': ['success', 'failure', 'not-available'],
#               'description': 'Result state of a completed action. This field has value not-available if the action is not finished.'},
#              'action-id': {'type': 'integer',
#               'format': 'uint16',
#               'maximum': 65535,
#               'minimum': 0,
#               'description': 'Uniquely identifies the invocation of an action. Identifies the invocation of an action when the managed object allows invocation of more than one action at a time.'},
#              'action-name': {'type': 'string',
#               'description': 'Name of the invoked asynchronous action.'},
#              'result-info': {'type': 'string',
#               'description': 'Textual description of the outcome/result of the action containing useful information for the NMS. If the action failed, it can contain an error message.'},
#              'progress-info': {'type': 'string',
#               'description': 'Textual information that describes the actual state of the action execution.'},
#              'additional-info': {'type': 'array',
#               'items': {'type': 'string'},
#               'description': 'Used for logging significant messages during execution of an action.'},
#              'progress-percentage': {'type': 'integer',
#               'format': 'uint8',
#               'maximum': 100,
#               'minimum': 0,
#               'description': 'Progress of the action.'},
#              'time-action-started': {'type': 'string',
#               'format': 'date-time',
#               'description': 'Date and time when the current action was started.'},
#              'time-action-completed': {'type': 'string',
#               'format': 'date-time',
#               'description': 'Date and time when the action was completed (successfully or unsuccessfully).'},
#              'time-of-last-status-update': {'type': 'string',
#               'format': 'date-time',
#               'description': 'Date and time when the struct member state was last updated.'}},
#             'additionalProperties': False},
#            'maxItems': 1,
#            'description': 'Reports the progress and final result of the ongoing (asynchronous) scheduled backup operation.',
#            'uniqueItems': True},
#           'next-scheduled-time': {'type': 'string',
#            'format': 'date-time',
#            'description': 'The date and time when the next scheduled event is triggered. This is the earliest scheduled event from the set of configured events, i.e. single, periodic, and calendar-based periodic events.'},
#           'auto-export-password': {'type': 'string',
#            'format': 'eric-adp-cm-secret',
#            'description': 'Password used by the backup scheduler when automatically exporting a scheduled backup. If leaf auto-export is set to ENABLED, this password is used for authentication when automatically exporting the scheduled backup. No need to specify this leaf if no password is required for accessing auto-export-uri.',
#            'eric-adp-is-passphrase': 'true'},
#           'scheduled-backup-name': {'type': 'string',
#            'default': 'SCHEDULED_BACKUP',
#            'description': 'The configurable portion of the scheduled backup name. The scheduled backups are named <scheduled-backup-name>-<creation date and time>, where creation date and time is of type yang:date-and-time.'},
#           'most-recently-created-auto-backup': {'type': 'string',
#            'description': 'The name of the scheduled backup created most recently by the backup scheduler.'}},
#          'description': 'Provides optional support for scheduling backup creation for the parent backup-manager. The scheduled backup events can be Single Events, Calendar Based Periodic Events, or Periodic Events as defined by the child lists.',
#          'additionalProperties': False},
#         'backup-type': {'type': 'string',
#          'description': 'Type of backup, for example System Data or User Data.'},
#         'housekeeping': {'type': 'object',
#          'properties': {'auto-delete': {'enum': ['enabled', 'disabled'],
#            'default': 'enabled',
#            'description': 'Determines whether automated housekeeping of manual backups is enabled. If ENABLED and the number of backups already stored on the ME is equal to the value of max-stored-manual-backups, the oldest backup is removed before creating a new one. If set to DISABLED, no backup is removed. Instead, when action create-backup() is invoked, it returns a failure parameter.'},
#           'max-stored-manual-backups': {'type': 'integer',
#            'format': 'uint16',
#            'default': '1',
#            'maximum': 65535,
#            'minimum': 0,
#            'description': 'Maximum number of manual backups, per backup type, to store in the ME. When this limit is reached, if auto-delete=ENABLED, BRM removes the oldest manual backup before creating a new one. Otherwise an error is returned when create-backup() is invoked and the NMS must perform the required housekeeping activity before attempting to create a new backup.'}},
#          'description': 'Provides optional support for automated housekeeping of manually created backups. If auto-delete is set to ENABLED before creating a new manual backup, BRM first checks the number of manual backups, and if the limit specified by the value of max-stored-manual-backups is reached, BRM removes the oldest manual backup before creating a new one.',
#          'additionalProperties': False},
#         'backup-domain': {'type': 'string',
#          'description': 'Backup domain, for example System.'},
#         'progress-report': {'type': 'array',
#          'items': {'type': 'object',
#           'required': ['time-action-started', 'time-of-last-status-update'],
#           'properties': {'state': {'enum': ['cancelling',
#              'running',
#              'finished',
#              'cancelled'],
#             'description': 'Current state of the action.'},
#            'result': {'enum': ['success', 'failure', 'not-available'],
#             'description': 'Result state of a completed action. This field has value not-available if the action is not finished.'},
#            'action-id': {'type': 'integer',
#             'format': 'uint16',
#             'maximum': 65535,
#             'minimum': 0,
#             'description': 'Uniquely identifies the invocation of an action. Identifies the invocation of an action when the managed object allows invocation of more than one action at a time.'},
#            'action-name': {'type': 'string',
#             'description': 'Name of the invoked asynchronous action.'},
#            'result-info': {'type': 'string',
#             'description': 'Textual description of the outcome/result of the action containing useful information for the NMS. If the action failed, it can contain an error message.'},
#            'progress-info': {'type': 'string',
#             'description': 'Textual information that describes the actual state of the action execution.'},
#            'additional-info': {'type': 'array',
#             'items': {'type': 'string'},
#             'description': 'Used for logging significant messages during execution of an action.'},
#            'progress-percentage': {'type': 'integer',
#             'format': 'uint8',
#             'maximum': 100,
#             'minimum': 0,
#             'description': 'Progress of the action.'},
#            'time-action-started': {'type': 'string',
#             'format': 'date-time',
#             'description': 'Date and time when the current action was started.'},
#            'time-action-completed': {'type': 'string',
#             'format': 'date-time',
#             'description': 'Date and time when the action was completed (successfully or unsuccessfully).'},
#            'time-of-last-status-update': {'type': 'string',
#             'format': 'date-time',
#             'description': 'Date and time when the struct member state was last updated.'}},
#           'additionalProperties': False},
#          'maxItems': 1,
#          'description': 'Represents the progress report and final result of the ongoing (asynchronous) action, for example create-backup. Supports only one action to be executed at a time.',
#          'uniqueItems': True}},
#        'additionalProperties': False},
#       'description': 'Top node for a backup-domain/type.',
#       'uniqueItems': True,
#       'eric-adp-actions': ['ericsson-brm:brm::backup-manager::create-backup',
#        'ericsson-brm:brm::backup-manager::delete-backup',
#        'ericsson-brm:brm::backup-manager::import-backup']}},
#     'description': 'Backup and Restore Management.',
#     'additionalProperties': False}},
#   'description': 'Generated by jsonschema-generator (1.21.0-38 2021-11-02 11:40:08 CET) from Yang module ericsson-brm (4.1.0) on Feb 15, 2022 9:00:28 PM. Features: [ericsson-brm:housekeeping, ericsson-brm:scheduler]. Deviations/extensions: [ericsson-brm-ext-adp]',
#   'eric-adp-name': 'eric-ctrl-bro',
#   'eric-adp-version': '1.3.0',
#   'eric-adp-genoptions': [{'encoding-format': 'eric-rfc7951-json'},
#    {'eric-adp-actions': True}],
#   'additionalProperties': False,
#   'eric-adp-yang-module': 'ericsson-brm',
#   'eric-adp-encoding-format': 'eric-rfc7951-json'},
#  'createTime': '2022-09-05T21:28:49.658885Z',
#  'modifiedTime': '2022-09-05T21:28:49.658885Z',
#  'actions': {'implementerUri': 'https://eric-ctrl-bro:7002/v2'},
#  'yangArchiveMd5': 'ab0e4c7472d8a5fa386427eb9a6431d4'}

# %%
url = f'{baseurl}/cm/api/v1/schemas/ietf-netconf-acm'
result = requests.get(url)
result.json()
# Out:
# {'name': 'ietf-netconf-acm',
#  'title': 'CMYP Network Configuration Access Control Model',
#  'jsonSchema': {'type': 'object',
#   'title': 'ietf-netconf-acm',
#   '$schema': 'http://json-schema.org/draft-07/schema#',
#   'properties': {'ietf-netconf-acm:nacm': {'type': 'object',
#     'properties': {'groups': {'type': 'object',
#       'properties': {'group': {'type': 'array',
#         'items': {'type': 'object',
#          'required': ['name'],
#          'properties': {'name': {'type': 'string',
#            'pattern': '^[^\\*].*$',
#            'description': 'Group name associated with this entry.'},
#           'user-name': {'type': 'array',
#            'items': {'type': 'string'},
#            'description': 'Each entry identifies the username of a member of the group associated with this entry.'},
#           'tailf-acm:gid': {'type': 'integer',
#            'description': "This leaf associates a numerical group ID with the group. When a OS command is executed on behalf of a user, supplementary group IDs are assigned based on 'gid' values for the groups that the use is a member of."}},
#          'additionalProperties': False},
#         'description': 'One NACM group entry. This list will only contain configured entries, not any entries learned from any transport protocols.',
#         'uniqueItems': True}},
#       'description': 'NETCONF access control groups.',
#       'additionalProperties': False},
#      'rule-list': {'type': 'array',
#       'items': {'type': 'object',
#        'required': ['name'],
#        'properties': {'name': {'type': 'string',
#          'description': 'Arbitrary name assigned to the rule-list.'},
#         'rule': {'type': 'array',
#          'items': {'type': 'object',
#           'required': ['action', 'name'],
#           'properties': {'name': {'type': 'string',
#             'description': 'Arbitrary name assigned to the rule.'},
#            'path': {'type': 'string',
#             'description': "Data node instance-identifier associated with the data node, action, or notification controlled by this rule. Configuration data or state data instance-identifiers start with a top-level data node. A complete instance-identifier is required for this type of path value. The special value '/' refers to all possible datastore contents."},
#            'action': {'enum': ['permit', 'deny'],
#             'description': 'The access control action associated with the rule. If a rule has been determined to match a particular request, then this object is used to determine whether to permit or deny the request.'},
#            'comment': {'type': 'string',
#             'description': 'A textual description of the access rule.'},
#            'rpc-name': {'type': 'string',
#             'description': "This leaf matches if it has the value '*' or if its value equals the requested protocol operation name."},
#            'module-name': {'type': 'string',
#             'default': '*',
#             'description': "Name of the module associated with this rule. This leaf matches if it has the value '*' or if the object being accessed is defined in the module with the specified module name."},
#            'access-operations': {'type': 'string',
#             'default': '*',
#             'description': "Access operations associated with this rule. This leaf matches if it has the value '*' or if the bit corresponding to the requested operation is set."},
#            'notification-name': {'type': 'string',
#             'description': "This leaf matches if it has the value '*' or if its value equals the requested notification name."},
#            'tailf-acm:context': {'type': 'string',
#             'default': '*',
#             'description': "This leaf matches if it has the value '*' or if its value identifies the agent that is requesting access, e.g. 'netconf' for NETCONF, 'cli' for CLI, or 'webui' for Web UI."},
#            'tailf-acm:log-if-permit': {'type': 'array',
#             'items': {'type': 'null'},
#             'description': 'If this leaf is present, access granted due to this rule is logged in the developer log. Otherwise, only denied access is logged. Mainly intended for debugging of rules.'}},
#           'additionalProperties': False},
#          'description': "One access control rule. Rules are processed in user-defined order until a match is found. A rule matches if 'module-name', 'rule-type', and 'access-operations' match the request. If a rule matches, the 'action' leaf determines whether or not access is granted.",
#          'uniqueItems': True},
#         'group': {'type': 'array',
#          'items': {'type': 'string'},
#          'description': "List of administrative groups that will be assigned the associated access rights defined by the 'rule' list. The string '*' indicates that all groups apply to the entry."},
#         'tailf-acm:cmdrule': {'type': 'array',
#          'items': {'type': 'object',
#           'required': ['action', 'name'],
#           'properties': {'name': {'type': 'string',
#             'description': 'Arbitrary name assigned to the rule.'},
#            'action': {'enum': ['permit', 'deny'],
#             'description': 'The access control action associated with the rule. If a rule is determined to match a particular request, then this object is used to determine whether to permit or deny the request.'},
#            'command': {'type': 'string',
#             'default': '*',
#             'description': 'Space-separated tokens representing the command. Refer to the Tail-f AAA documentation for further details.'},
#            'comment': {'type': 'string',
#             'description': 'A textual description of the access rule.'},
#            'context': {'type': 'string',
#             'default': '*',
#             'description': "This leaf matches if it has the value '*' or if its value identifies the agent that is requesting access, i.e. 'cli' for CLI or 'webui' for Web UI."},
#            'log-if-permit': {'type': 'array',
#             'items': {'type': 'null'},
#             'description': 'If this leaf is present, access granted due to this rule is logged in the developer log. Otherwise, only denied access is logged. Mainly intended for debugging of rules.'},
#            'access-operations': {'type': 'string',
#             'default': '*',
#             'description': "Access operations associated with this rule. This leaf matches if it has the value '*' or if the bit corresponding to the requested operation is set."}},
#           'additionalProperties': False},
#          'description': "One command access control rule. Command rules control access to CLI commands and Web UI functions. Rules are processed in user-defined order until a match is found. A rule matches if 'context', 'command', and 'access-operations' match the request. If a rule matches, the 'action' leaf determines if access is granted or not.",
#          'uniqueItems': True}},
#        'additionalProperties': False},
#       'description': 'An ordered collection of access control rules.',
#       'uniqueItems': True},
#      'enable-nacm': {'type': 'boolean',
#       'default': 'true',
#       'description': "Enables or disables all NETCONF access control enforcement. If 'true', then enforcement is enabled. If 'false', then enforcement is disabled."},
#      'exec-default': {'enum': ['permit', 'deny'],
#       'default': 'permit',
#       'description': 'Controls whether exec access is granted if no appropriate rule is found for a particular protocol operation request.'},
#      'read-default': {'enum': ['permit', 'deny'],
#       'default': 'permit',
#       'description': 'Controls whether read access is granted if no appropriate rule is found for a particular read request.'},
#      'write-default': {'enum': ['permit', 'deny'],
#       'default': 'deny',
#       'description': 'Controls whether create, update, or delete access is granted if no appropriate rule is found for a particular write request.'},
#      'denied-operations': {'type': 'integer',
#       'description': 'Number of times since the server last restarted that a protocol operation request was denied.'},
#      'denied-data-writes': {'type': 'integer',
#       'description': 'Number of times since the server last restarted that a protocol operation request to alter a configuration datastore was denied.'},
#      'denied-notifications': {'type': 'integer',
#       'description': 'Number of times since the server last restarted that a notification was dropped for a subscription because access to the event type was denied.'},
#      'enable-external-groups': {'type': 'boolean',
#       'default': 'true',
#       'description': "Controls whether the server uses the groups reported by the NETCONF transport layer when it assigns the user to a set of NACM groups. If this leaf has the value 'false', any group names reported by the transport layer are ignored by the server."},
#      'tailf-acm:cmd-exec-default': {'enum': ['permit', 'deny'],
#       'default': 'permit',
#       'description': 'Controls whether command exec access is granted if no appropriate cmdrule is found for a particular command exec request.'},
#      'tailf-acm:cmd-read-default': {'enum': ['permit', 'deny'],
#       'default': 'permit',
#       'description': 'Controls whether command read access is granted if no appropriate cmdrule is found for a particular command read request.'},
#      'tailf-acm:log-if-default-permit': {'type': 'array',
#       'items': {'type': 'null'},
#       'description': "If this leaf is present, access granted due to one of /nacm/read-default, /nacm/write-default, /nacm/exec-default /nacm/cmd-read-default, or /nacm/cmd-exec-default being set to 'permit' is logged in the developer log. Otherwise, only denied access is logged. Mainly intended for debugging of rules."}},
#     'description': 'Parameters for NETCONF access control model.',
#     'additionalProperties': False}},
#   'description': 'Generated by Yang2JsonSchema (1.17.0-36 2020-09-11 10:10:11 CEST) on Sep 11, 2020 1:39:49 PM from Yang module: ietf-netconf-acm (2018-02-14), with features: [], and with deviations/extensions: [in/tailf-acm.yang]',
#   'eric-adp-name': 'ietf-netconf-acm',
#   'eric-adp-version': '0.1.2',
#   'eric-adp-genoptions': [],
#   'additionalProperties': False},
#  'createTime': '2022-09-08T14:19:45.852669Z',
#  'modifiedTime': '2022-09-08T14:19:45.852669Z'}

# %% [markdown]
# ### Delete a schema

# %%
url = f'{baseurl}/cm/api/v1/schemas/ericsson-brm'
result = requests.delete(url)
result.json()
# Out:
# {'message': "Deleted schema 'ericsson-brm'"}

# %% [markdown]
# ### List action implementers

# %%
url = f'{baseurl}/cm/api/v1/schemas/ericsson-brm/actions'
result = requests.get(url)
result.json()
# Out:
# {'implementerUri': 'https://eric-ctrl-bro:7002/v2'}

# %% [markdown]
# ## Subscriptions

# %% [markdown]
# ### List Subscriptions

# %%
url = f'{baseurl}/cm/api/v1/subscriptions'
result = requests.get(url)
result.json()
# Out:
# [{'id': 'ericsson-brm', 'leaseSeconds': 157679412}]

# %% [markdown]
# ### Detail a subscription

# %%
url = f'{baseurl}/cm/api/v1/subscriptions/ericsson-brm'
result = requests.get(url)
result.json()
# Out:
# {'id': 'ericsson-brm',
#  'configName': 'ericsson-brm',
#  'event': ['configUpdated'],
#  'updateNotificationFormat': 'patch',
#  'callback': 'https://eric-ctrl-bro:7004/v3/confighandler',
#  'leaseSeconds': 273}

# %%
url = f'{baseurl}/cm/api/v1/subscriptions/ericsson-brm'
result = requests.get(url)
result.json()
# Out:
# {'id': 'ericsson-brm',
#  'configName': 'ericsson-brm',
#  'event': ['configUpdated'],
#  'updateNotificationFormat': 'patch',
#  'callback': 'https://eric-ctrl-bro:7004/v3/confighandler',
#  'leaseSeconds': 160}

# %%
url = f'{baseurl}/cm/api/v1/subscriptions/ericsson-brm'
result = requests.get(url)
result.json()
# Out:
# {'id': 'ericsson-brm',
#  'configName': 'ericsson-brm',
#  'event': ['configUpdated'],
#  'updateNotificationFormat': 'patch',
#  'callback': 'https://eric-ctrl-bro:7004/v3/confighandler',
#  'leaseSeconds': 157679760}

# %% [markdown]
# ### Delete subsription

# %%
url = f'{baseurl}/cm/api/v1/subscriptions/ericsson-brm'
result = requests.delete(url)
result.json()
# Out:
# {'message': "Deleted subscription 'ericsson-brm'"}

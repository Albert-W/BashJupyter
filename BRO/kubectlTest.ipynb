# %%
import k8sclient

# %%
KUBE = k8sclient.KubernetesClient()

# %%
KUBE.list_pods_from_namespace("eyicwux-test1")
# Out:
# {'api_version': 'v1',
#  'items': [{'api_version': None,
#             'kind': None,
#             'metadata': {'annotations': {'cni.projectcalico.org/podIP': '192.168.36.19/32',
#                                          'cni.projectcalico.org/podIPs': '192.168.36.19/32',
#                                          'ericsson.com/product-name': 'test-service-basic',
#                                          'ericsson.com/product-number': 'CXC '
#                                                                         '000 '
#                                                                         '0000',
#                                          'ericsson.com/product-revision': '4.11.0-6'},
#                          'cluster_name': None,
#                          'creation_timestamp': datetime.datetime(2021, 11, 22, 22, 2, 8, tzinfo=tzutc()),
#                          'deletion_grace_period_seconds': None,
#                          'deletion_timestamp': None,
# ...

# %%
KUBE.get_pod_ip_address("eric-data-key-value-database-rd-operand-9rbvd", "eyicwux-test1")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-5daae246b1e3> in <module>
# ----> 1 KUBE.get_pod_ip_address("eric-data-key-value-database-rd-operand-9rbvd", "eyicwux-test1")
#
# /c/Users/eyicwux/Documents/github/BashJupyter/k8sclient.py in get_pod_ip_address(self, name, namespace)
#    1195
#    1196         if pod_addr == '':
# -> 1197             raise RuntimeError('No ip address found for pod {}'.format(name))
#    1198
#    1199         return pod_addr
#
# RuntimeError: No ip address found for pod eric-data-key-value-database-rd-operand-9rbvd

# %%
KUBE.get_pod_ip_address("bravo-0", "eyicwux-test1")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-ade2cd73837e> in <module>
# ----> 1 KUBE.get_pod_ip_address("bravo-0", "eyicwux-test1")
#
# /c/Users/eyicwux/Documents/github/BashJupyter/k8sclient.py in get_pod_ip_address(self, name, namespace)
#    1195
#    1196         if pod_addr == '':
# -> 1197             raise RuntimeError('No ip address found for pod {}'.format(name))
#    1198
#    1199         return pod_addr
#
# RuntimeError: No ip address found for pod bravo-0

# %%
KUBE.get_pod_ip("bravo-0")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e6247ccab121> in <module>
# ----> 1 KUBE.get_pod_ip("bravo-0")
#
# /c/Users/eyicwux/Documents/github/BashJupyter/k8sclient.py in get_pod_ip(self, name)
#    1352         while True:
#    1353             try:
# ...

# %%
KUBE.get_namespace_pod_details("bravo-0")
# Out:
# {'api_version': 'v1',
#  'items': [],
#  'kind': 'PodList',
#  'metadata': {'_continue': None,
#               'remaining_item_count': None,
#               'resource_version': '654462736',
#               'self_link': '/api/v1/namespaces/bravo-0/pods'}}

# %%
KUBE.get_namespace_pod_details("bravo-0")

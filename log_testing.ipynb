# %%
"""
Setup:
pip3 install elasticsearch
deploy chart-repo/eric-data-search-engine, chart-repo/eric-data-search-engine, local BRO build
port forwarding eric-data-search-engine-ingest-*:9200 to  localhost:9200
port forwarding eric-ctrl-bro-0:7001 to localhost:7001
"""
# Out:
# '\nSetup:\npip3 install elasticsearch\ndeploy chart-repo/eric-data-search-engine, chart-repo/eric-data-search-engine, local BRO build\nport forwarding eric-data-search-engine-ingest-*:9200 to  localhost:9200\nport forwarding eric-ctrl-bro-0:7001 to localhost:7001\n'

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch('http://10.120.217.249:9200')

# %%
import json

import requests as r

# %%
es.info()
# Out:
# {'name': 'eric-data-search-engine-ingest-895bbccf7-7ddnm',
#  'cluster_name': 'eric-data-search-engine',
#  'cluster_uuid': 'YbusCkk7SxGN2Fp_xdW4Kw',
#  'version': {'number': '7.8.1',
#   'build_flavor': 'oss',
#   'build_type': 'tar',
#   'build_hash': 'b5ca9c58fb664ca8bf9e4057fc229b3396bf3a89',
#   'build_date': '2020-07-21T16:40:44.668009Z',
#   'build_snapshot': False,
#   'lucene_version': '8.5.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
es.cat.indices()
# Out:
# 'green open adp-app-logs-2021.08.31 dbciACtQQk-hwp2wZ_P-jA 5 1  11 0 213.1kb 106.4kb\ngreen open adp-app-logs-2021.08.30 liWAfXR8RxuoZ9W3hhy-UQ 5 1 388 0 851.8kb 454.4kb\ngreen open adp-app-logs-2021.08.27 W__DEx4XTUGs_vM2eu1IPg 5 1  72 0 600.5kb 307.2kb\ngreen open adp-app-logs-2021.08.26 TCr5eB7PS_adm597pbCmAw 5 1  91 0 734.6kb 369.2kb\ngreen open adp-app-logs-2021.08.25 PHOB-anOS8CVlnk-KoqD5A 5 1  10 0 213.9kb 106.9kb\ngreen open adp-app-logs-2021.08.24 -jM_cvzlQXCHt2k8CA75kQ 5 1  53 0 579.4kb 289.7kb\ngreen open my-index-01             2mnlnLP0RquSvwWrcq4VFw 5 1   0 0     2kb     1kb\n'

# %%
index = es.cat.indices().split("\n")[0].split(" ")[2]
index
# Out:
# 'adp-app-logs-2021.08.31'

# %%
"check the logs so far"
res = es.search(
    index=index,
    body={"query": {"match": {"service_id" : "eric-ctrl-bro"}}},
    sort = "@timestamp:ascending",
    size=10000)
res = sorted(res["hits"]["hits"], key=lambda x: x["_source"]["@timestamp"])
#data = [(x["_source"]["@timestamp"] +" : " + x["_source"]["severity"] + " : " + x["_source"]["message"]) for x in res]

print(json.dumps(res, indent=2))
# Out:
# [
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "SZyNnHsBJeAju-avjVh5",
#     "_score": 0.15387988,
#     "_source": {
#       "port": 2399,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:06.619Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Starting BackupAndRestoreApplication using Java 14.0.2 on IE-00002941 with PID 19868 (C:\\Users\\eyicwux\\Documents\\Ericsson\\PlanB\\BRO\\64784\\backupandrestore\\service\\target\\classes started by eyicwux in C:\\Users\\eyicwux\\Documents\\Ericsson\\PlanB\\BRO\\64784\\backupandrestore\\service)",
#       "@timestamp": "2021-08-31T14:12:06.815Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "SJyNnHsBJeAju-avilj4",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:06.633Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "No active profile set, falling back to default profiles: default",
#       "@timestamp": "2021-08-31T14:12:06.911Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 11345,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "SpyNnHsBJeAju-avm1je",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:11.077Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Starting Backup and Restore Orchestrator Version: version_placeholder",
#       "@timestamp": "2021-08-31T14:12:11.252Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 49271,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "S5yNnHsBJeAju-avnFj-",
#     "_score": 0.15387988,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:11.398Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Execute loop started",
#       "@timestamp": "2021-08-31T14:12:11.540Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 27559,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "TJyNnHsBJeAju-avnljK",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:11.827Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Not enabling kubernetes agent discovery",
#       "@timestamp": "2021-08-31T14:12:11.999Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 12293,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "TZyNnHsBJeAju-avn1gb",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:11.927Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Not enabling Message Bus notifications",
#       "@timestamp": "2021-08-31T14:12:12.079Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 57202,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "TpyNnHsBJeAju-avoFgg",
#     "_score": 0.12767884,
#     "_source": {
#       "port": 65208,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:12.128Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Creating grpc server at port 3000",
#       "@timestamp": "2021-08-31T14:12:12.341Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "T5yNnHsBJeAju-avolgq",
#     "_score": 0.13956004,
#     "_source": {
#       "port": 29032,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:12.312Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "GRPC server has TLS disabled",
#       "@timestamp": "2021-08-31T14:12:12.865Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "UJyNnHsBJeAju-avpVia",
#     "_score": 0.12767884,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:13.614Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Started BackupAndRestoreApplication in 8.152 seconds (JVM running for 9.318)",
#       "@timestamp": "2021-08-31T14:12:13.744Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 20894,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "UZyNnHsBJeAju-avp1gO",
#     "_score": 0.15387988,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:13.992Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "BackupManager:configuration-data",
#       "@timestamp": "2021-08-31T14:12:14.116Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 4651,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "UpyNnHsBJeAju-avp1h2",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:12:13.992Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "BackupManager:DEFAULT",
#       "@timestamp": "2021-08-31T14:12:14.220Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 57465,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "U5yPnHsBJeAju-avMlgs",
#     "_score": 0.22232392,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:13:55.039Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Registering agent <agentId: \"bravo1\"",
#       "@timestamp": "2021-08-31T14:13:55.255Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 12447,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "X5yQnHsBJeAju-avWFgs",
#     "_score": 0.15387988,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:10.386Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Performing action cleanup",
#       "@timestamp": "2021-08-31T14:15:10.523Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 11783,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "YJyQnHsBJeAju-avWFhq",
#     "_score": 0.12767884,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:10.391Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Job starting for HOUSEKEEPING action - <3096>",
#       "@timestamp": "2021-08-31T14:15:10.591Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 30296,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "YZyQnHsBJeAju-avWFi0",
#     "_score": 0.22232392,
#     "_source": {
#       "port": 34340,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:10.404Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Performing action cleanup",
#       "@timestamp": "2021-08-31T14:15:10.663Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "YpyQnHsBJeAju-avWFjs",
#     "_score": 0.15387988,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:10.405Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Job starting for HOUSEKEEPING_DELETE_BACKUP action - <34201>",
#       "@timestamp": "2021-08-31T14:15:10.721Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 22274,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "Y5yQnHsBJeAju-avXFgv",
#     "_score": 0.13956004,
#     "_source": {
#       "port": 1483,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:11.427Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Finished deleting backup <myBackup158> of backupManager <DEFAULT>",
#       "@timestamp": "2021-08-31T14:15:11.556Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "ZJyQnHsBJeAju-avXFiz",
#     "_score": 0.12767884,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:11.427Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Successfully completing action HOUSEKEEPING_DELETE_BACKUP - <34201>",
#       "@timestamp": "2021-08-31T14:15:11.689Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 20407,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "ZZyQnHsBJeAju-avXVgS",
#     "_score": 0.22232392,
#     "_source": {
#       "port": 15259,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:11.427Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Performing action cleanup",
#       "@timestamp": "2021-08-31T14:15:11.782Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "ZpyQnHsBJeAju-avXVhU",
#     "_score": 0.15387988,
#     "_source": {
#       "port": 36558,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:11.431Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Finished Action execution HOUSEKEEPING_DELETE_BACKUP : <34201> final result:SUCCESS",
#       "@timestamp": "2021-08-31T14:15:11.850Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "Z5yQnHsBJeAju-avXVia",
#     "_score": 0.15387988,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:11.432Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "BackupManager's housekeeping <DEFAULT> current value: <auto-delete:enabled max-stored-manual-backups:1> new value: <auto-delete:enabled max-stored-manual-backups:1>",
#       "@timestamp": "2021-08-31T14:15:11.919Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 9470,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "aJyQnHsBJeAju-avYFhx",
#     "_score": 0.12767884,
#     "_source": {
#       "port": 11013,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.493Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Successfully completing action HOUSEKEEPING - <3096>",
#       "@timestamp": "2021-08-31T14:15:12.645Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "aZyQnHsBJeAju-avYFi5",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.494Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Performing action cleanup",
#       "@timestamp": "2021-08-31T14:15:12.718Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 13752,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "apyQnHsBJeAju-avYVgf",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.503Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Performing action cleanup",
#       "@timestamp": "2021-08-31T14:15:12.819Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 22781,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "a5yQnHsBJeAju-avYVi1",
#     "_score": 0.13956004,
#     "_source": {
#       "port": 1203,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.504Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Job starting for CREATE_BACKUP action - <50357>",
#       "@timestamp": "2021-08-31T14:15:12.971Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "bJyQnHsBJeAju-avYVj7",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.505Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "The application product information could not be retrieved: <Missing the required parameter 'namespace' when calling readNamespacedConfigMap(Async)>. The BRO product information will be used instead.",
#       "@timestamp": "2021-08-31T14:15:13.041Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "warning",
#       "facility": "local0",
#       "port": 43557,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "bZyQnHsBJeAju-avYlhL",
#     "_score": 0.12767884,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.577Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Created TarGzFile C:\\Users\\eyicwux\\Documents\\Ericsson\\PlanB\\BRO\\64784\\backupandrestore\\service\\backups\\DEFAULT\\myBackup159\\backupManagers.tar.gz",
#       "@timestamp": "2021-08-31T14:15:13.120Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 35641,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "bpyQnHsBJeAju-avYliz",
#     "_score": 0.13956004,
#     "_source": {
#       "port": 8187,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.656Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Backing up BRO configuration in C:\\Users\\eyicwux\\Documents\\Ericsson\\PlanB\\BRO\\64784\\backupandrestore\\service\\backups\\DEFAULT\\myBackup159\\backupManagers.tar.gz",
#       "@timestamp": "2021-08-31T14:15:13.224Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "b5yQnHsBJeAju-avYlj0",
#     "_score": 0.15387988,
#     "_source": {
#       "port": 26241,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.754Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Triggering backup preparation on agent <bravo1>",
#       "@timestamp": "2021-08-31T14:15:13.285Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "cJyQnHsBJeAju-avY1i3",
#     "_score": 0.15387988,
#     "_source": {
#       "port": 45197,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.918Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Sending control message <action: BACKUP",
#       "@timestamp": "2021-08-31T14:15:13.481Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "d5yQnHsBJeAju-avY1j5",
#     "_score": 0.22232392,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:12.991Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Received Stage Complete message <action: BACKUP",
#       "@timestamp": "2021-08-31T14:15:13.547Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 6718,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "fpyQnHsBJeAju-avZFhI",
#     "_score": 0.13956004,
#     "_source": {
#       "port": 17947,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.252Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Updating progress of agent <bravo1> with success <true> for stage <PreparingBackupJobStage>",
#       "@timestamp": "2021-08-31T14:15:13.629Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "f5yQnHsBJeAju-avZFjL",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.256Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Sending control message <action: BACKUP",
#       "@timestamp": "2021-08-31T14:15:13.754Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 28851,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "hJyQnHsBJeAju-avZVgU",
#     "_score": 0.12767884,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.278Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Agent is opening backup data channel",
#       "@timestamp": "2021-08-31T14:15:13.833Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 47923,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "hZyQnHsBJeAju-avZViL",
#     "_score": 0.12767884,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.418Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Received message metadata {",
#       "@timestamp": "2021-08-31T14:15:13.950Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 58567,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "j5yQnHsBJeAju-avZVjT",
#     "_score": 0.13956004,
#     "_source": {
#       "port": 28186,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.505Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "backup data stream connection closed",
#       "@timestamp": "2021-08-31T14:15:14.025Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "kJyQnHsBJeAju-avZlge",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.557Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Updating status of fragment bravo1_1 from agent bravo1 to SUCCESSFUL",
#       "@timestamp": "2021-08-31T14:15:14.100Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 30531,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "kZyQnHsBJeAju-avZlhk",
#     "_score": 0.22232392,
#     "_source": {
#       "port": 1523,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.699Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Received Stage Complete message <action: BACKUP",
#       "@timestamp": "2021-08-31T14:15:14.166Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "mJyQnHsBJeAju-avZljg",
#     "_score": 0.13956004,
#     "_source": {
#       "port": 1125,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.972Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Updating progress of agent <bravo1> with success <true> for stage <ExecutingBackupJobStage>",
#       "@timestamp": "2021-08-31T14:15:14.294Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "mZyQnHsBJeAju-avZ1gd",
#     "_score": 0.12767884,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.975Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Sending control message <action: BACKUP",
#       "@timestamp": "2021-08-31T14:15:14.354Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 29087,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "npyQnHsBJeAju-avZ1iG",
#     "_score": 0.12767884,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:13.980Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Received Stage Complete message <action: BACKUP",
#       "@timestamp": "2021-08-31T14:15:14.456Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 13652,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "pZyQnHsBJeAju-avZ1jD",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:14.239Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Updating progress of agent <bravo1> with success <true> for stage <PostActionBackupJobStage>",
#       "@timestamp": "2021-08-31T14:15:14.521Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 23797,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "ppyQnHsBJeAju-avaFgC",
#     "_score": 0.12767884,
#     "_source": {
#       "port": 32551,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:14.240Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Completed backup <myBackup159>",
#       "@timestamp": "2021-08-31T14:15:14.583Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "p5yQnHsBJeAju-avalga",
#     "_score": 0.22232392,
#     "_source": {
#       "port": 23028,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:14.981Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Finished backup <myBackup159>",
#       "@timestamp": "2021-08-31T14:15:15.120Z",
#       "@version": "1"
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "qJyQnHsBJeAju-avaliF",
#     "_score": 0.13956004,
#     "_source": {
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:14.981Z",
#       "type": "syslog",
#       "tags": [
#         "syslog5424"
#       ],
#       "message": "Successfully completing action CREATE_BACKUP - <50357>",
#       "@timestamp": "2021-08-31T14:15:15.226Z",
#       "service_id": "eric-ctrl-bro",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "@version": "1",
#       "severity": "info",
#       "facility": "local0",
#       "port": 50615,
#       "logplane": "adp-app-logs",
#       "metadata": {
#         "proc_id": "19868"
#       }
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.08.31",
#     "_type": "_doc",
#     "_id": "qZyQnHsBJeAju-avaljH",
#     "_score": 0.13956004,
#     "_source": {
#       "port": 38353,
#       "tags": [
#         "syslog5424"
#       ],
#       "facility": "local0",
#       "service_id": "eric-ctrl-bro",
#       "type": "syslog",
#       "metadata": {
#         "proc_id": "19868"
#       },
#       "logplane": "adp-app-logs",
#       "version": "1.0.0",
#       "timestamp": "2021-08-31T14:15:14.981Z",
#       "kubernetes": {
#         "node": {
#           "name": "IE-00002941"
#         }
#       },
#       "severity": "info",
#       "message": "Performing action cleanup",
#       "@timestamp": "2021-08-31T14:15:15.293Z",
#       "@version": "1"
#     }
#   }
# ]

# %%
len(res)
# Out:
# 46

# %%
# cause BRO to spit out an error
body = {
    "action": "CREATE_BACKUP",
    "payload": {
#        "backupName": "myBackup"
        "backupName" : dumb_name_250
    }
}
res = r.post("http://localhost:7001/v1/backup-manager/DEFAULT/action", json=body)

# %%
import requests
baseurl = 'http://10.120.217.249:9200'

# %%
result = requests.get(baseurl)
result.json()
# Out:
# {'name': 'eric-data-search-engine-ingest-895bbccf7-7ddnm',
#  'cluster_name': 'eric-data-search-engine',
#  'cluster_uuid': 'YbusCkk7SxGN2Fp_xdW4Kw',
#  'version': {'number': '7.8.1',
#   'build_flavor': 'oss',
#   'build_type': 'tar',
#   'build_hash': 'b5ca9c58fb664ca8bf9e4057fc229b3396bf3a89',
#   'build_date': '2020-07-21T16:40:44.668009Z',
#   'build_snapshot': False,
#   'lucene_version': '8.5.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
url = baseurl + '/_search'
body={"query": {"match_all": {}}},
result = requests.post(url, json = body)
result.text
# Out:
# '{"error":{"root_cause":[{"type":"parsing_exception","reason":"Expected [START_OBJECT] but found [START_ARRAY]","line":1,"col":1}],"type":"parsing_exception","reason":"Expected [START_OBJECT] but found [START_ARRAY]","line":1,"col":1},"status":400}'

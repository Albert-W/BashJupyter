# %%
"""
Setup:
pip3 install elasticsearch
deploy chart-repo/eric-data-search-engine, chart-repo/eric-data-search-engine, local BRO build
port forwarding eric-data-search-engine-ingest-*:9200 to  localhost:9200
port forwarding eric-ctrl-bro-0:7001 to localhost:7001
"""
# Out:
# '\nSetup:\npip3 install elasticsearch\ndeploy chart-repo/eric-data-search-engine, chart-repo/eric-data-search-engine, local BRO build\nport forwarding eric-data-search-engine-ingest-*:9200 to  localhost:9200\nport forwarding eric-ctrl-bro-0:7001 to localhost:7001\n'

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(['http://10.120.217.249:9200'])

# %%
import json

import requests as r

# %%
es.info()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedProductError                   Traceback (most recent call last)
# <ipython-input-24-f69669341f07> in <module>
# ----> 1 es.info()
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     166                 if p in kwargs:
#     167                     params[p] = kwargs.pop(p)
# --> 168             return func(*args, params=params, headers=headers, **kwargs)
#     169
#     170         return _wrapped
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/client/__init__.py in info(self, params, headers)
#     292         `<https://www.elastic.co/guide/en/elasticsearch/reference/7.14/index.html>`_
#     293         """
# --> 294         return self.transport.perform_request(
#     295             "GET", "/", params=params, headers=headers
#     296         )
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     411         # If '_verified_elasticsearch' isn't 'True' then we raise an error.
#     412         if self._verified_elasticsearch is not True:
# --> 413             _ProductChecker.raise_error(self._verified_elasticsearch)
#     414
#     415         for attempt in range(self.max_retries + 1):
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/transport.py in raise_error(cls, state)
#     628                 "and we do not support this unknown product"
#     629             )
# --> 630         raise UnsupportedProductError(message)
#     631
#     632     @classmethod
#
# UnsupportedProductError: The client noticed that the server is not a supported distribution of Elasticsearch

# %%
es.cat.indices()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedProductError                   Traceback (most recent call last)
# <ipython-input-20-9d6fb56f4746> in <module>
# ----> 1 es.cat.indices()
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     166                 if p in kwargs:
#     167                     params[p] = kwargs.pop(p)
# --> 168             return func(*args, params=params, headers=headers, **kwargs)
#     169
#     170         return _wrapped
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/client/cat.py in indices(self, index, params, headers)
#     186         :arg v: Verbose mode. Display column headers
#     187         """
# --> 188         return self.transport.perform_request(
#     189             "GET", _make_path("_cat", "indices", index), params=params, headers=headers
#     190         )
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     411         # If '_verified_elasticsearch' isn't 'True' then we raise an error.
#     412         if self._verified_elasticsearch is not True:
# --> 413             _ProductChecker.raise_error(self._verified_elasticsearch)
#     414
#     415         for attempt in range(self.max_retries + 1):
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/transport.py in raise_error(cls, state)
#     628                 "and we do not support this unknown product"
#     629             )
# --> 630         raise UnsupportedProductError(message)
#     631
#     632     @classmethod
#
# UnsupportedProductError: The client noticed that the server is not a supported distribution of Elasticsearch

# %%
index = es.cat.indices().split("\n")[0].split(" ")[2]
index
# Out:
# ---------------------------------------------------------------------------
# UnsupportedProductError                   Traceback (most recent call last)
# <ipython-input-21-68e242ca9954> in <module>
# ----> 1 index = es.cat.indices().split("\n")[0].split(" ")[2]
#       2 index
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     166                 if p in kwargs:
#     167                     params[p] = kwargs.pop(p)
# --> 168             return func(*args, params=params, headers=headers, **kwargs)
#     169
#     170         return _wrapped
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/client/cat.py in indices(self, index, params, headers)
#     186         :arg v: Verbose mode. Display column headers
#     187         """
# --> 188         return self.transport.perform_request(
#     189             "GET", _make_path("_cat", "indices", index), params=params, headers=headers
#     190         )
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     411         # If '_verified_elasticsearch' isn't 'True' then we raise an error.
#     412         if self._verified_elasticsearch is not True:
# --> 413             _ProductChecker.raise_error(self._verified_elasticsearch)
#     414
#     415         for attempt in range(self.max_retries + 1):
#
# ~/.local/lib/python3.8/site-packages/elasticsearch/transport.py in raise_error(cls, state)
#     628                 "and we do not support this unknown product"
#     629             )
# --> 630         raise UnsupportedProductError(message)
#     631
#     632     @classmethod
#
# UnsupportedProductError: The client noticed that the server is not a supported distribution of Elasticsearch

# %%
"check the logs so far"
res = es.search(
    index=index,
    body={"query": {"match_all": {}}},
    sort = "@timestamp:ascending",
    size=10000)
res = sorted(res["hits"]["hits"], key=lambda x: x["_source"]["@timestamp"])
#data = [(x["_source"]["@timestamp"] +" : " + x["_source"]["severity"] + " : " + x["_source"]["message"]) for x in res]

print(json.dumps(res, indent=2))
# Out:
# [
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "9OrsQXkBZULZMEPMYtyN",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:44:35.035+01:00",
#       "version": "1.0.0",
#       "message": "INFO ThreadPoolTaskScheduler: Shutting down ExecutorService 'taskScheduler'",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:44:35.035+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:44:36.197Z",
#       "port": 50078,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "9ersQXkBZULZMEPMYtyO",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:44:35.035+01:00",
#       "version": "1.0.0",
#       "message": "INFO ThreadPoolTaskExecutor: Shutting down ExecutorService 'applicationTaskExecutor'",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:44:35.035+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:44:36.197Z",
#       "port": 50080,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "9urtQXkBZULZMEPMmNxO",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "WARN",
#       "timestamp8601": "2021-05-06T14:46:00.000+01:00",
#       "version": "1.0.0",
#       "message": "WARN Jackson2ObjectMapperBuilder: For Jackson Kotlin classes support please add \"com.fasterxml.jackson.module:jackson-module-kotlin\" to the classpath",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:00.000+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:00.486Z",
#       "port": 50980,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "9-rtQXkBZULZMEPMqtzt",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO EnableEncryptablePropertiesBeanFactoryPostProcessor: Post-processing PropertySource instances",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.304Z",
#       "port": 51048,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "-OrtQXkBZULZMEPMq9yM",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO EncryptablePropertySourceConverter: Converting PropertySource servletConfigInitParams [org.springframework.core.env.PropertySource$StubPropertySource] to EncryptablePropertySourceWrapper",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.432Z",
#       "port": 51054,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "-ertQXkBZULZMEPMq9yM",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO EncryptablePropertySourceConverter: Converting PropertySource configurationProperties [org.springframework.boot.context.properties.source.ConfigurationPropertySourcesPropertySource] to AOP Proxy",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.434Z",
#       "port": 51058,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "-urtQXkBZULZMEPMq9yM",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO EncryptablePropertySourceConverter: Converting PropertySource servletContextInitParams [org.springframework.core.env.PropertySource$StubPropertySource] to EncryptablePropertySourceWrapper",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.435Z",
#       "port": 51056,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "--rtQXkBZULZMEPMq9zP",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO EncryptablePropertySourceConverter: Converting PropertySource systemEnvironment [org.springframework.boot.env.SystemEnvironmentPropertySourceEnvironmentPostProcessor$OriginAwareSystemEnvironmentPropertySource] to EncryptableSystemEnvironmentPropertySourceWrapper",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.494Z",
#       "port": 51060,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "_OrtQXkBZULZMEPMq9zP",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO EncryptablePropertySourceConverter: Converting PropertySource random [org.springframework.boot.env.RandomValuePropertySource] to EncryptablePropertySourceWrapper",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.495Z",
#       "port": 51064,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "_ertQXkBZULZMEPMq9zP",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO EncryptablePropertySourceConverter: Converting PropertySource applicationConfig: [classpath:/application.properties] [org.springframework.boot.env.OriginTrackedMapPropertySource] to EncryptableMapPropertySourceWrapper",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.496Z",
#       "port": 51066,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "_urtQXkBZULZMEPMq9zP",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO EncryptablePropertySourceConverter: Converting PropertySource systemProperties [org.springframework.core.env.PropertiesPropertySource] to EncryptableMapPropertySourceWrapper",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.497Z",
#       "port": 51062,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "_-rtQXkBZULZMEPMq9zP",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO DefaultLazyPropertyFilter: Property Filter custom Bean not found with name 'encryptablePropertyFilter'. Initializing Default Property Filter",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.524Z",
#       "port": 51068,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "AertQXkBZULZMEPMrN2W",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO DefaultLazyPropertyDetector: Property Detector custom Bean not found with name 'encryptablePropertyDetector'. Initializing Default Property Detector",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.732Z",
#       "port": 51078,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "AOrtQXkBZULZMEPMrN2W",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:05.005+01:00",
#       "version": "1.0.0",
#       "message": "INFO DefaultLazyPropertyResolver: Property Resolver custom Bean not found with name 'encryptablePropertyResolver'. Initializing Default Property Resolver",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:05.005+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:05.732Z",
#       "port": 51080,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "AurtQXkBZULZMEPMs93M",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:07.007+01:00",
#       "version": "1.0.0",
#       "message": "INFO TomcatWebServer: Tomcat initialized with port(s): 7001 (http)",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:07.007+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:07.551Z",
#       "port": 51108,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "A-rtQXkBZULZMEPMs93M",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:07.007+01:00",
#       "version": "1.0.0",
#       "message": "INFO Http11NioProtocol: Initializing ProtocolHandler [\"http-nio-7001\"]",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:07.007+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:07.570Z",
#       "port": 51110,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "BOrtQXkBZULZMEPMs93M",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:07.007+01:00",
#       "version": "1.0.0",
#       "message": "INFO StandardEngine: Starting Servlet engine: [Apache Tomcat/9.0.41]",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:07.007+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:07.574Z",
#       "port": 51114,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "BertQXkBZULZMEPMs93M",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:07.007+01:00",
#       "version": "1.0.0",
#       "message": "INFO StandardService: Starting service [Tomcat]",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:07.007+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:07.574Z",
#       "port": 51112,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "B-rtQXkBZULZMEPMtd2u",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:07.007+01:00",
#       "version": "1.0.0",
#       "message": "INFO [/]: Initializing Spring embedded WebApplicationContext",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:07.007+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:08.059Z",
#       "port": 51118,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   },
#   {
#     "_index": "adp-app-logs-2021.05.06",
#     "_type": "_doc",
#     "_id": "BurtQXkBZULZMEPMtd2u",
#     "_score": 1.0,
#     "_source": {
#       "logsource": "INFO",
#       "timestamp8601": "2021-05-06T14:46:07.007+01:00",
#       "version": "1.0.0",
#       "message": "INFO ServletWebServerApplicationContext: Root WebApplicationContext: initialization completed in 7371 ms",
#       "logplane": "adp-app-logs",
#       "@version": "1",
#       "timestamp": "2021-05-06T14:46:07.007+01:00",
#       "type": "syslog",
#       "@timestamp": "2021-05-06T13:46:08.059Z",
#       "port": 51120,
#       "tags": [
#         "syslog3164",
#         "_dateparsefailure"
#       ]
#     }
#   }
# ]

# %%
len(res)
# Out:
# 20

# %%
# cause BRO to spit out an error
body = {
    "action": "CREATE_BACKUP",
    "payload": {
#        "backupName": "myBackup"
        "backupName" : dumb_name_250
    }
}
res = r.post("http://localhost:7001/v1/backup-manager/DEFAULT/action", json=body)

# %%
import requests
baseurl = 'http://10.120.217.249:9200'

# %%
result = requests.get(baseurl)
result.json()
# Out:
# {'name': 'eric-data-search-engine-ingest-895bbccf7-7ddnm',
#  'cluster_name': 'eric-data-search-engine',
#  'cluster_uuid': 'YbusCkk7SxGN2Fp_xdW4Kw',
#  'version': {'number': '7.8.1',
#   'build_flavor': 'oss',
#   'build_type': 'tar',
#   'build_hash': 'b5ca9c58fb664ca8bf9e4057fc229b3396bf3a89',
#   'build_date': '2020-07-21T16:40:44.668009Z',
#   'build_snapshot': False,
#   'lucene_version': '8.5.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
url = baseurl + '/_search'
body={"query": {"match_all": {}}},
result = requests.post(url, json = body)
result.text
# Out:
# '{"error":{"root_cause":[{"type":"parsing_exception","reason":"Expected [START_OBJECT] but found [START_ARRAY]","line":1,"col":1}],"type":"parsing_exception","reason":"Expected [START_OBJECT] but found [START_ARRAY]","line":1,"col":1},"status":400}'
